# %% [markdown]
# # A Data Driven Approach to European Ski Resorts 2
#
#
# ## Our Dataset
#
# Our dataset features a sample of 376 european ski resorts provided by  ski-resort-stats.com, made availble through kaggle.
#
# [Kaggle Dataset](https://www.kaggle.com/thomasnibb/european-ski-resorts)
#
# [Data Source: Ski-resort-stats.com](Ski-resort-stats.com)
#
# ## Potential Questions

# %% [markdown]
# # Data Dictionary
#
# |Column Name| Description|
# |-----------|-----------|
# |**#**|Rownumber|
# |**Resort**|The name at the ski & snowboard resort.
# |**Country**| The name of the country in which the resort is located.|
# |**HighestPoint**|The highest mountain point at the ski resort.|
# |**LowestPoint**|The lowest possible point to ski at the ski resort.|
# |**DayPassPriceAdult**| The price shows what it costs for 1 adult for 1 day in the main season in Euros €.|
# |**BeginnerSlope**|The total amount of “beginner” slopes in kilometer at the resort. “Beginner slopes” contains “children”, “blue” and “green” slopes.|
# |**IntermediateSlope**| The total amount of “intermediate” slopes in kilometer at the resort.“Intermediate slopes” contains “red” slopes. |
# |**DifficultSlope**| The total amount of “difficult” slopes in kilometer at the resort.“Difficult slopes” contains “black”, “advanced” and”expert” slopes.|
# |**TotalSlope**| The sum of “beginner slopes” + “intermediate slopes” + “difficult slopes”|
# |**Snowparks**| Does the resort have one or more snowparks, or not?|
# |**NightSki**|Does the resort offer skiing on illuminated slopes?|
# |**SurfaceLifts**| The amount of lifts in this category: T-bar, Sunkidslift, Rope lifts and people mower.|
# |**ChairLifts**| The total amount of chairlifts.|
# |**GondolaLifts**|The amount of lifts in this category: Gondola, Train lifts, Funicular, Combined gondola and chairlifts, Helicopter lifts, Snowcats and Aerial tramways.|
# |**TotalLifts**| The sum of “surface lifts etc” + “gondola etc” + “chairlifts etc”|
# |**LiftCapacity**| How many passengers can the lift system at the ski resort mowe in one hour?|
# |**SnowCannons**| The total amount of snow cannons at the ski resort.|

# %% [markdown]
# # Data Cleaning
#
# Data cleaning is done before the analysis.
#
# Clean data leads to accurate analysis.
#
# A Typical Work Flow is 80% cleaning vs 20% analyzing.
#
# ### Things to look for:
# * wrong language
# * wrong label
# * missing information
# * duplicates
# * invalid inputs
# * wrong criteria
#     * free vs paid
#     * country
#     * type

# %%
from csv import reader
o_file = open('European_Ski_Resorts.csv')
r_file = reader(o_file)
ski_data = list(r_file)
ski_data_head = ski_data[0]
ski_data = ski_data[1:]

# %%
ski_data_head
# Out:
# ['',
#  'Resort',
#  'Country',
#  'HighestPoint',
#  'LowestPoint',
#  'DayPassPriceAdult',
#  'BeginnerSlope',
#  'IntermediateSlope',
#  'DifficultSlope',
#  'TotalSlope',
#  'Snowparks',
#  'NightSki',
#  'SurfaceLifts',
#  'ChairLifts',
#  'GondolaLifts',
#  'TotalLifts',
#  'LiftCapacity',
#  'SnowCannons']

# %%
ski_data
# Out:
# [['1',
#   'Alpendorf (Ski amedé)',
#   'Austria',
#   '1980',
#   '740',
#   '52',
#   '30',
#   '81',
#   '4',
#   '115',
#   'Yes',
#   'No',
#   '22',
#   '16',
#   '11',
#   '49',
#   '75398',
#   '600'],
#  ['2',
#   'Soldeu-Pas de la Casa/\u200bGrau Roig/\u200bEl Tarter/\u200bCanillo/\u200bEncamp (Grandvalira)',
#   'Andorra',
#   '2640',
#   '1710',
#   '47',
#   '100',
#   '77',
#   '33',
#   '210',
#   'Yes',
#   'Yes',
#   '37',
#   '28',
#   '7',
#   '72',
#   '99017',
#   '1032'],
#  ['3',
#   'Oberau (Wildschönau)',
#   'Austria',
#   '1130',
#   '900',
#   '30',
#   '1',
#   '0',
#   '1',
#   '2',
#   'No',
#   'No',
#   '2',
#   '0',
#   '0',
#   '2',
#   '1932',
#   '0'],
#  ['4',
#   'Dachstein West',
#   'Austria',
#   '1620',
#   '780',
#   '42',
#   '15',
#   '33',
#   '3',
#   '51',
#   'Yes',
#   'Yes',
#   '25',
#   '8',
#   '3',
#   '36',
#   '32938',
#   '163'],
#  ['5',
#   'Rosa Khutor',
#   'Southern Russia',
#   '2320',
#   '940',
#   '22',
#   '30',
#   '26',
#   '21',
#   '77',
#   'Yes',
#   'No',
#   '6',
#   '11',
#   '10',
#   '27',
#   '49228',
#   '450'],
#  ['6',
#   'Białka Tatrzańska-Kotelnica-\u200bKaniówka-\u200bBania',
#   'Poland',
#   '910',
#   '680',
#   '23',
#   '12',
#   '3',
#   '0',
#   '16',
#   'Yes',
#   'Yes',
#   '7',
#   '1',
#   '0',
#   '8',
#   '28020',
#   '0'],
#  ['7',
#   'Vitosha-Sofia',
#   'Bulgaria',
#   '2290',
#   '726',
#   '18',
#   '12',
#   '6',
#   '2',
#   '20',
#   'No',
#   'Yes',
#   '8',
#   '5',
#   '2',
#   '15',
#   '12450',
#   '0'],
#  ['8',
#   'Szczyrk-Skrzyczne',
#   'Poland',
#   '1257',
#   '524',
#   '20',
#   '22',
#   '7',
#   '4',
#   '35',
#   'No',
#   'No',
#   '11',
#   '4',
#   '1',
#   '16',
#   '22500',
#   '0'],
#  ['9',
#   'Jahorina',
#   'Bosnia and Herzegovina',
#   '1889',
#   '920',
#   '20',
#   '3',
#   '19',
#   '3',
#   '25',
#   'No',
#   'Yes',
#   '5',
#   '5',
#   '1',
#   '11',
#   '16230',
#   '0'],
#  ['10',
#   'Kobla-Bohinj',
#   'Slovenia',
#   '1480',
#   '540',
#   '22',
#   '12',
#   '10',
#   '1',
#   '23',
#   'No',
#   'No',
#   '3',
#   '3',
#   '0',
#   '6',
#   '5720',
#   '30'],
#  ['11',
#   'Aillons-Margériaz',
#   'France',
#   '1785',
#   '1370',
#   '19',
#   '18',
#   '4',
#   '1',
#   '24',
#   'No',
#   'No',
#   '7',
#   '1',
#   '0',
#   '8',
#   '10025',
#   '0'],
#  ['12',
#   'Gornaya Karusel',
#   'Southern Russia',
#   '960',
#   '540',
#   '22',
#   '4',
#   '15',
#   '1',
#   '20',
#   'No',
#   'No',
#   '3',
#   '1',
#   '0',
#   '4',
#   '15740',
#   '0'],
#  ['13',
#   'Kaiseregg-\u200bRiggisalp-Schwarzsee',
#   'Switzerland',
#   '1750',
#   '1050',
#   '34',
#   '14',
#   '5',
#   '1',
#   '20',
#   'Yes',
#   'Yes',
#   '11',
#   '3',
#   '1',
#   '15',
#   '5790',
#   '46'],
#  ['14',
#   'St. Pierre de Chartreuse-Le Planolet',
#   'France',
#   '1800',
#   '900',
#   '21',
#   '18',
#   '12',
#   '5',
#   '35',
#   'No',
#   'No',
#   '3',
#   '2',
#   '0',
#   '5',
#   '12610',
#   '35'],
#  ['15',
#   'Buchenberg-Buching-Halblech-',
#   'Germany',
#   '1140',
#   '810',
#   '25',
#   '2',
#   '4',
#   '0',
#   '6',
#   'No',
#   'No',
#   '2',
#   '1',
#   '0',
#   '3',
#   '2800',
#   '0'],
#  ['16',
#   'Méribel (Les 3 Vallées)',
#   'France',
#   '3230',
#   '1110',
#   '61',
#   '312',
#   '216',
#   '72',
#   '600',
#   'Yes',
#   'Yes',
#   '62',
#   '63',
#   '40',
#   '165',
#   '250860',
#   '2383'],
#  ['17',
#   '\u200bLes Menuires (Les 3 Vallées)',
#   'France',
#   '3230',
#   '1110',
#   '61',
#   '312',
#   '216',
#   '72',
#   '600',
#   'Yes',
#   'Yes',
#   '62',
#   '63',
#   '40',
#   '165',
#   '250860',
#   '2383'],
#  ['18',
#   'Les Sybelles-Le Corbier-\u200bLa Toussuire-\u200bLes Bottières-\u200bSt Colomban des Villards-\u200bSt Sorlin-\u200bSt Jean d’Arves',
#   'France',
#   '2620',
#   '1100',
#   '44',
#   '53',
#   '239',
#   '18',
#   '310',
#   'Yes',
#   'Yes',
#   '44',
#   '28',
#   '0',
#   '72',
#   '83807',
#   '514'],
#  ['19',
#   'Le Grand Massif-Flaine-\u200bLes Carroz-\u200bMorillon-\u200bSamoëns-\u200bSixt',
#   'France',
#   '2476',
#   '694',
#   '47',
#   '135',
#   '95',
#   '35',
#   '265',
#   'Yes',
#   'No',
#   '34',
#   '29',
#   '9',
#   '72',
#   '97624',
#   '1100'],
#  ['20',
#   'Megève-\u200bSaint-Gervais',
#   'France',
#   '2353',
#   '850',
#   '46',
#   '98',
#   '134',
#   '31',
#   '263',
#   'Yes',
#   'Yes',
#   '50',
#   '27',
#   '9',
#   '86',
#   '106362',
#   '888'],
#  ['21',
#   'Laax-\u200bFlims-\u200bFalera',
#   'Switzerland',
#   '3018',
#   '1100',
#   '68',
#   '88',
#   '81',
#   '19',
#   '188',
#   'Yes',
#   'No',
#   '13',
#   '9',
#   '11',
#   '33',
#   '46116',
#   '300'],
#  ['22',
#   'Vars-\u200bRisoul-La Forêt Blanche',
#   'France',
#   '2750',
#   '1650',
#   '39',
#   '75',
#   '90',
#   '20',
#   '185',
#   'Yes',
#   'Yes',
#   '32',
#   '17',
#   '2',
#   '51',
#   '50145',
#   '0'],
#  ['23',
#   'Kicking Horse',
#   'France',
#   '1608',
#   '1500',
#   '39',
#   '56',
#   '93',
#   '30',
#   '180',
#   'Yes',
#   'No',
#   '21',
#   '13',
#   '4',
#   '38',
#   '40680',
#   '281'],
#  ['24',
#   'Le Grand Domaine-Valmorel-\u200bDoucy-\u200bCelliers-\u200bSt François Longchamp',
#   'France',
#   '2550',
#   '1250',
#   '44',
#   '115',
#   '35',
#   '15',
#   '165',
#   'Yes',
#   'No',
#   '36',
#   '17',
#   '3',
#   '56',
#   '60248',
#   '332'],
#  ['25',
#   'Galibier Thabor-Valmeinier-\u200bValloire',
#   'France',
#   '2594',
#   '1430',
#   '39',
#   '75',
#   '60',
#   '15',
#   '150',
#   'Yes',
#   'Yes',
#   '12',
#   '17',
#   '2',
#   '31',
#   '43300',
#   '400'],
#  ['26',
#   'Zillertal Arena-Zell am Ziller-\u200bGerlos-\u200bKönigsleiten-\u200bHochkrimml',
#   'Austria',
#   '2500',
#   '580',
#   '52',
#   '43',
#   '89',
#   '11',
#   '143',
#   'Yes',
#   'No',
#   '22',
#   '21',
#   '13',
#   '56',
#   '89415',
#   '792'],
#  ['27',
#   'La Molina-\u200bMasella-Alp2500',
#   'Spain',
#   '2531',
#   '1616',
#   '45',
#   '76',
#   '47',
#   '18',
#   '141',
#   'Yes',
#   'Yes',
#   '19',
#   '13',
#   '1',
#   '33',
#   '39750',
#   '1010'],
#  ['28',
#   'Auron-Saint-Etienne-de-Tinée-',
#   'France',
#   '1600',
#   '1150',
#   '34',
#   '60',
#   '45',
#   '30',
#   '135',
#   'Yes',
#   'No',
#   '7',
#   '9',
#   '3',
#   '19',
#   '25030',
#   '440'],
#  ['29',
#   'Alta Badia',
#   'Italy',
#   '2550',
#   '1324',
#   '52',
#   '70',
#   '52',
#   '8',
#   '130',
#   'Yes',
#   'No',
#   '18',
#   '30',
#   '11',
#   '59',
#   '89327',
#   '391'],
#  ['30',
#   'La Clusaz-\u200bManigod',
#   'France',
#   '2477',
#   '1040',
#   '37',
#   '62',
#   '40',
#   '23',
#   '125',
#   'Yes',
#   'Yes',
#   '28',
#   '14',
#   '7',
#   '49',
#   '59346',
#   '223'],
#  ['31',
#   'Espace Villard Corrençon-Villard-de-Lans-\u200bCorrençon-en-Vercors',
#   'France',
#   '2050',
#   '1050',
#   '36',
#   '50',
#   '50',
#   '25',
#   '125',
#   'Yes',
#   'No',
#   '18',
#   '7',
#   '3',
#   '28',
#   '26600',
#   '339'],
#  ['32',
#   'Val Cenis-Lanslevillard-\u200bLanslebourg-\u200bTermignon',
#   'France',
#   '2800',
#   '1300',
#   '36',
#   '73',
#   '42',
#   '10',
#   '125',
#   'Yes',
#   'Yes',
#   '13',
#   '13',
#   '2',
#   '28',
#   '39824',
#   '200'],
#  ['33',
#   'Isola 2000',
#   'France',
#   '2603',
#   '1800',
#   '34',
#   '75',
#   '35',
#   '10',
#   '120',
#   'Yes',
#   'Yes',
#   '12',
#   '7',
#   '3',
#   '22',
#   '21807',
#   '430'],
#  ['34',
#   'Obersaxen-\u200bMundaun-\u200bVal Lumnezia',
#   'Switzerland',
#   '2310',
#   '1201',
#   '51',
#   '60',
#   '40',
#   '20',
#   '120',
#   'Yes',
#   'Yes',
#   '10',
#   '9',
#   '0',
#   '19',
#   '20720',
#   '297'],
#  ['35',
#   'Les 7 Laux-Prapoutel-\u200bLe Pleynet-\u200bPipay',
#   'France',
#   '2400',
#   '1350',
#   '36',
#   '46',
#   '36',
#   '38',
#   '120',
#   'Yes',
#   'No',
#   '15',
#   '8',
#   '1',
#   '24',
#   '32232',
#   '200'],
#  ['36',
#   'Corvatsch-\u200bFurtschellas',
#   'Switzerland',
#   '3303',
#   '1797',
#   '69',
#   '13',
#   '89',
#   '17',
#   '120',
#   'Yes',
#   'Yes',
#   '5',
#   '6',
#   '3',
#   '14',
#   '18510',
#   '0'],
#  ['37',
#   'Nassfeld-Hermagor',
#   'Austria',
#   '2002',
#   '600',
#   '46',
#   '30',
#   '69',
#   '11',
#   '110',
#   'Yes',
#   'Yes',
#   '16',
#   '9',
#   '5',
#   '30',
#   '49386',
#   '483'],
#  ['38',
#   'Mondolè Ski-Artesina-\u200bFrabosa Soprana-\u200bPrato Nevoso',
#   'Italy',
#   '807',
#   '803',
#   '33',
#   '42',
#   '51',
#   '11',
#   '105',
#   'Yes',
#   'Yes',
#   '19',
#   '14',
#   '0',
#   '33',
#   '26068',
#   '0'],
#  ['39',
#   'Aletsch Arena-Riederalp-\u200bBettmeralp-\u200bFiesch Eggishorn',
#   'Switzerland',
#   '1845',
#   '759',
#   '53',
#   '42',
#   '50',
#   '12',
#   '104',
#   'Yes',
#   'Yes',
#   '18',
#   '8',
#   '12',
#   '38',
#   '41109',
#   '258'],
#  ['40',
#   'Bad Kleinkirchheim-\u200bSt. Oswald',
#   'Austria',
#   '2055',
#   '1087',
#   '47',
#   '18',
#   '77',
#   '8',
#   '103',
#   'Yes',
#   'Yes',
#   '17',
#   '7',
#   '4',
#   '28',
#   '31186',
#   '800'],
#  ['41',
#   'Bardonecchia',
#   'Italy',
#   '2694',
#   '1312',
#   '36',
#   '54',
#   '38',
#   '8',
#   '100',
#   'Yes',
#   'No',
#   '13',
#   '9',
#   '1',
#   '23',
#   '27588',
#   '0'],
#  ['42',
#   'Saint-Lary-Soulan',
#   'France',
#   '1600',
#   '812',
#   '42',
#   '60',
#   '30',
#   '10',
#   '100',
#   'Yes',
#   'Yes',
#   '17',
#   '11',
#   '3',
#   '31',
#   '38733',
#   '290'],
#  ['43',
#   'Orcières Merlette 1850',
#   'France',
#   '2725',
#   '1850',
#   '34',
#   '55',
#   '38',
#   '7',
#   '100',
#   'Yes',
#   'No',
#   '20',
#   '7',
#   '3',
#   '30',
#   '29605',
#   '0'],
#  ['44',
#   'Dévoluy-Superdévoluy-\u200bLa Joue du Loup',
#   'France',
#   '2450',
#   '1450',
#   '36',
#   '60',
#   '30',
#   '10',
#   '100',
#   'Yes',
#   'No',
#   '18',
#   '5',
#   '1',
#   '24',
#   '27646',
#   '180'],
#  ['45',
#   'Grand Tourmalet-\u200bPic du Midi-La Mongie-\u200bBarèges',
#   'France',
#   '2500',
#   '1250',
#   '42',
#   '58',
#   '35',
#   '7',
#   '100',
#   'Yes',
#   'No',
#   '21',
#   '15',
#   '2',
#   '38',
#   '40231',
#   '0'],
#  ['46',
#   'Parsenn (Davos Klosters)',
#   'Switzerland',
#   '2844',
#   '810',
#   '61',
#   '20',
#   '60',
#   '16',
#   '96',
#   'Yes',
#   'No',
#   '4',
#   '6',
#   '8',
#   '18',
#   '26795',
#   '169'],
#  ['47',
#   'Åre',
#   'Sweden',
#   '1274',
#   '380',
#   '45',
#   '45',
#   '38',
#   '8',
#   '91',
#   'Yes',
#   'Yes',
#   '27',
#   '5',
#   '4',
#   '36',
#   '39000',
#   '0'],
#  ['48',
#   'Alto Sangro-Roccaraso-\u200bRivisondoli',
#   'Italy',
#   '2141',
#   '1309',
#   '41',
#   '37',
#   '32',
#   '20',
#   '90',
#   'No',
#   'No',
#   '11',
#   '11',
#   '4',
#   '26',
#   '36602',
#   '0'],
#  ['49',
#   'Chamrousse',
#   'France',
#   '2250',
#   '1400',
#   '34',
#   '45',
#   '35',
#   '10',
#   '90',
#   'Yes',
#   'Yes',
#   '8',
#   '7',
#   '1',
#   '16',
#   '24398',
#   '78'],
#  ['50',
#   'Valberg-\u200bBeuil les Launes',
#   'France',
#   '2020',
#   '1412',
#   '32',
#   '45',
#   '35',
#   '10',
#   '90',
#   'Yes',
#   'No',
#   '22',
#   '7',
#   '0',
#   '29',
#   '25940',
#   '400'],
#  ['51',
#   'Adelboden-\u200bLenk-Chuenisbärgli-\u200bSilleren-\u200bHahnenmoos-\u200bMetsch',
#   'Switzerland',
#   '1260',
#   '1072',
#   '55',
#   '44',
#   '38',
#   '6',
#   '88',
#   'Yes',
#   'Yes',
#   '12',
#   '8',
#   '6',
#   '26',
#   '34620',
#   '500'],
#  ['52',
#   'Rinderberg-\u200bSaanerslochgrat-\u200bHorneggli-Zweisimmen-\u200bSaanenmöser-\u200bSchönried-\u200bSt. Stephan',
#   'Switzerland',
#   '2011',
#   '948',
#   '54',
#   '62',
#   '21',
#   '4',
#   '88',
#   'Yes',
#   'Yes',
#   '9',
#   '8',
#   '4',
#   '21',
#   '18360',
#   '0'],
#  ['53',
#   'Graukogel-Bad Gastein',
#   'Austria',
#   '2007',
#   '1079',
#   '36',
#   '3',
#   '6',
#   '2',
#   '11',
#   'No',
#   'No',
#   '1',
#   '2',
#   '0',
#   '3',
#   '3352',
#   '0'],
#  ['54',
#   'Les Portes du Mont-Blanc-Combloux-\u200bMegève le Jaillet-\u200bLa Giettaz',
#   'France',
#   '1835',
#   '1113',
#   '35',
#   '28',
#   '50',
#   '7',
#   '85',
#   'No',
#   'No',
#   '16',
#   '8',
#   '1',
#   '25',
#   '29842',
#   '0'],
#  ['55',
#   'Le Grand Bornand',
#   'France',
#   '2100',
#   '1000',
#   '37',
#   '49',
#   '27',
#   '8',
#   '84',
#   'Yes',
#   'Yes',
#   '18',
#   '13',
#   '2',
#   '33',
#   '36904',
#   '233'],
#  ['56',
#   'Kaltenbach-Hochzillertal-\u200bHochfügen-SKi-optimal-',
#   'Austria',
#   '2378',
#   '600',
#   '52',
#   '28',
#   '41',
#   '13',
#   '83',
#   'Yes',
#   'Yes',
#   '22',
#   '12',
#   '5',
#   '39',
#   '59933',
#   '400'],
#  ['57',
#   'Grimentz-\u200bZinal',
#   'Switzerland',
#   '2900',
#   '1570',
#   '51',
#   '26',
#   '28',
#   '26',
#   '80',
#   'Yes',
#   'No',
#   '13',
#   '5',
#   '3',
#   '21',
#   '19345',
#   '96'],
#  ['58',
#   'Civetta-Alleghe-\u200bSelva di Cadore-\u200bPalafavera-\u200bZoldo',
#   'Italy',
#   '2100',
#   '1000',
#   '43',
#   '30',
#   '44',
#   '6',
#   '80',
#   'Yes',
#   'Yes',
#   '10',
#   '10',
#   '3',
#   '23',
#   '33289',
#   '100'],
#  ['59',
#   'Ax les Thermes',
#   'France',
#   '1400',
#   '720',
#   '37',
#   '40',
#   '25',
#   '15',
#   '80',
#   'Yes',
#   'No',
#   '11',
#   '6',
#   '2',
#   '19',
#   '21320',
#   '0'],
#  ['60',
#   'Damüls Mellau',
#   'Austria',
#   '2050',
#   '690',
#   '49',
#   '37',
#   '39',
#   '1',
#   '79',
#   'Yes',
#   'No',
#   '10',
#   '13',
#   '2',
#   '25',
#   '37160',
#   '130'],
#  ['61',
#   'Zell am See',
#   'Austria',
#   '2000',
#   '760',
#   '50',
#   '30',
#   '28',
#   '19',
#   '77',
#   'Yes',
#   'Yes',
#   '9',
#   '10',
#   '8',
#   '27',
#   '48407',
#   '450'],
#  ['62',
#   'Cerler',
#   'Spain',
#   '2621',
#   '1505',
#   '42',
#   '35',
#   '27',
#   '14',
#   '76',
#   'Yes',
#   'No',
#   '10',
#   '9',
#   '0',
#   '19',
#   '20670',
#   '0'],
#  ['63',
#   'Three Peaks Dolomites-Helm-\u200bStiergarten-\u200bRotwand-\u200bKreuzbergpass',
#   'Italy',
#   '2200',
#   '1130',
#   '51',
#   '17',
#   '39',
#   '18',
#   '75',
#   'Yes',
#   'No',
#   '20',
#   '4',
#   '6',
#   '30',
#   '21535',
#   '250'],
#  ['64',
#   'Puy St. Vincent',
#   'France',
#   '2677',
#   '1407',
#   '34',
#   '28',
#   '34',
#   '13',
#   '75',
#   'Yes',
#   'Yes',
#   '4',
#   '8',
#   '0',
#   '12',
#   '17155',
#   '95'],
#  ['65',
#   'Folgaria-\u200bFiorentini',
#   'Italy',
#   '1850',
#   '1200',
#   '40',
#   '36',
#   '32',
#   '5',
#   '74',
#   'Yes',
#   'No',
#   '13',
#   '17',
#   '0',
#   '30',
#   '35900',
#   '280'],
#  ['66',
#   'Titlis-Engelberg',
#   'Switzerland',
#   '3020',
#   '1000',
#   '57',
#   '34',
#   '26',
#   '12',
#   '72',
#   'Yes',
#   'No',
#   '7',
#   '6',
#   '7',
#   '20',
#   '23316',
#   '180'],
#  ['67',
#   'Trysil',
#   'Norway',
#   '1100',
#   '415',
#   '46',
#   '33',
#   '18',
#   '20',
#   '71',
#   'Yes',
#   'Yes',
#   '29',
#   '7',
#   '0',
#   '36',
#   '36182',
#   '418'],
#  ['68',
#   'Nauders am Reschenpass-Bergkastel',
#   'Austria',
#   '2850',
#   '1400',
#   '42',
#   '24',
#   '34',
#   '13',
#   '71',
#   'Yes',
#   'No',
#   '11',
#   '5',
#   '1',
#   '17',
#   '17651',
#   '92'],
#  ['69',
#   'Grossarltal-\u200bDorfgastein',
#   'Austria',
#   '2033',
#   '850',
#   '50',
#   '25',
#   '43',
#   '1',
#   '70',
#   'Yes',
#   'No',
#   '7',
#   '8',
#   '5',
#   '20',
#   '29710',
#   '0'],
#  ['70',
#   'Katschberg',
#   'Austria',
#   '2220',
#   '1066',
#   '46',
#   '10',
#   '50',
#   '10',
#   '70',
#   'Yes',
#   'Yes',
#   '9',
#   '6',
#   '2',
#   '17',
#   '26458',
#   '750'],
#  ['71',
#   'Valfréjus',
#   'France',
#   '2737',
#   '1550',
#   '29',
#   '40',
#   '20',
#   '10',
#   '70',
#   'Yes',
#   'No',
#   '5',
#   '4',
#   '1',
#   '10',
#   '15800',
#   '80'],
#  ['72',
#   'Savognin',
#   'Switzerland',
#   '2713',
#   '1200',
#   '50',
#   '32',
#   '38',
#   '0',
#   '70',
#   'Yes',
#   'Yes',
#   '10',
#   '2',
#   '1',
#   '13',
#   '14000',
#   '100'],
#  ['73',
#   'Scuol-Motta Naluns',
#   'Switzerland',
#   '2785',
#   '1250',
#   '50',
#   '27',
#   '32',
#   '11',
#   '70',
#   'Yes',
#   'No',
#   '6',
#   '6',
#   '1',
#   '13',
#   '18000',
#   '136'],
#  ['74',
#   'Passo San Pellegrino-\u200bFalcade',
#   'Italy',
#   '2513',
#   '1190',
#   '47',
#   '20',
#   '38',
#   '8',
#   '67',
#   'Yes',
#   'No',
#   '6',
#   '9',
#   '2',
#   '17',
#   '24030',
#   '0'],
#  ['75',
#   'Piau Engaly',
#   'France',
#   '2560',
#   '1420',
#   '37',
#   '35',
#   '22',
#   '8',
#   '65',
#   'Yes',
#   'No',
#   '5',
#   '5',
#   '0',
#   '10',
#   '13615',
#   '40'],
#  ['76',
#   'Flumserberg',
#   'Switzerland',
#   '665',
#   '425',
#   '51',
#   '10',
#   '38',
#   '17',
#   '65',
#   'Yes',
#   'Yes',
#   '9',
#   '8',
#   '4',
#   '21',
#   '30867',
#   '0'],
#  ['77',
#   'Super Sauze',
#   'France',
#   '2450',
#   '1400',
#   '30',
#   '35',
#   '20',
#   '10',
#   '65',
#   'Yes',
#   'No',
#   '18',
#   '4',
#   '0',
#   '22',
#   '17948',
#   '100'],
#  ['78',
#   'Bukovel',
#   'Ukraine',
#   '1372',
#   '890',
#   '32',
#   '26',
#   '28',
#   '11',
#   '65',
#   'Yes',
#   'Yes',
#   '3',
#   '15',
#   '0',
#   '18',
#   '33839',
#   '0'],
#  ['79',
#   'La Norma',
#   'France',
#   '2750',
#   '1350',
#   '29',
#   '17',
#   '43',
#   '5',
#   '65',
#   'Yes',
#   'No',
#   '7',
#   '5',
#   '1',
#   '13',
#   '13290',
#   '126'],
#  ['80',
#   'Pal-\u200bArinsal-La Massana-Vallnord-',
#   'Andorra',
#   '1550',
#   '1230',
#   '37',
#   '31',
#   '24',
#   '8',
#   '63',
#   'Yes',
#   'No',
#   '15',
#   '12',
#   '4',
#   '31',
#   '37400',
#   '296'],
#  ['81',
#   'Arabba',
#   'Italy',
#   '2478',
#   '1602',
#   '49',
#   '32',
#   '22',
#   '8',
#   '62',
#   'Yes',
#   'No',
#   '3',
#   '16',
#   '4',
#   '23',
#   '43973',
#   '620'],
#  ['82',
#   'Wildkogel-Neukirchen-\u200bBramberg',
#   'Austria',
#   '2150',
#   '820',
#   '44',
#   '28',
#   '25',
#   '9',
#   '62',
#   'Yes',
#   'Yes',
#   '15',
#   '4',
#   '5',
#   '24',
#   '27388',
#   '335'],
#  ['83',
#   'Hintertux Glacier',
#   'Austria',
#   '3250',
#   '1500',
#   '52',
#   '14',
#   '35',
#   '11',
#   '60',
#   'Yes',
#   'No',
#   '10',
#   '6',
#   '6',
#   '22',
#   '38852',
#   '260'],
#  ['84',
#   'Disentis 3000',
#   'Switzerland',
#   '2833',
#   '1227',
#   '49',
#   '20',
#   '30',
#   '10',
#   '60',
#   'Yes',
#   'No',
#   '9',
#   '3',
#   '1',
#   '13',
#   '10990',
#   '4'],
#  ['85',
#   'Belalp-Blatten',
#   'Switzerland',
#   '3118',
#   '1322',
#   '49',
#   '20',
#   '20',
#   '20',
#   '60',
#   'Yes',
#   'No',
#   '8',
#   '3',
#   '2',
#   '13',
#   '13640',
#   '0'],
#  ['86',
#   'San Martino di Castrozza',
#   'Italy',
#   '2357',
#   '1404',
#   '44',
#   '16',
#   '32',
#   '12',
#   '60',
#   'Yes',
#   'Yes',
#   '7',
#   '14',
#   '3',
#   '24',
#   '29859',
#   '150'],
#  ['87',
#   'Meiringen-Hasliberg',
#   'Switzerland',
#   '1055',
#   '600',
#   '50',
#   '20',
#   '34',
#   '6',
#   '60',
#   'No',
#   'Yes',
#   '6',
#   '4',
#   '5',
#   '15',
#   '16381',
#   '75'],
#  ['88',
#   'Toggenburg-Wildhaus-\u200bUnterwasser-\u200bAlt St. Johann',
#   'Switzerland',
#   '2262',
#   '900',
#   '52',
#   '10',
#   '45',
#   '5',
#   '60',
#   'Yes',
#   'Yes',
#   '18',
#   '3',
#   '4',
#   '25',
#   '19956',
#   '55'],
#  ['89',
#   'Alpe di Siusi-Seiser Alm-',
#   'Italy',
#   '1669',
#   '1000',
#   '54',
#   '14',
#   '45',
#   '1',
#   '60',
#   'Yes',
#   'No',
#   '9',
#   '15',
#   '3',
#   '27',
#   '35624',
#   '70'],
#  ['90',
#   'Le Lioran',
#   'France',
#   '1850',
#   '1160',
#   '31',
#   '30',
#   '20',
#   '10',
#   '60',
#   'Yes',
#   'Yes',
#   '13',
#   '8',
#   '1',
#   '22',
#   '25195',
#   '241'],
#  ['91',
#   'Saint Luc-\u200bChandolin-Anniviers-',
#   'Switzerland',
#   '3025',
#   '1655',
#   '47',
#   '20',
#   '30',
#   '10',
#   '60',
#   'Yes',
#   'No',
#   '11',
#   '3',
#   '1',
#   '15',
#   '10350',
#   '104'],
#  ['92',
#   'Les Karellis',
#   'France',
#   '2520',
#   '1600',
#   '27',
#   '26',
#   '25',
#   '9',
#   '60',
#   'Yes',
#   'No',
#   '10',
#   '6',
#   '0',
#   '16',
#   '17452',
#   '98'],
#  ['93',
#   'Peyragudes',
#   'France',
#   '2400',
#   '1600',
#   '40',
#   '30',
#   '26',
#   '4',
#   '60',
#   'Yes',
#   'No',
#   '8',
#   '9',
#   '0',
#   '17',
#   '22791',
#   '230'],
#  ['94',
#   'Leysin',
#   'Switzerland',
#   '2205',
#   '1250',
#   '45',
#   '43',
#   '15',
#   '2',
#   '60',
#   'Yes',
#   'No',
#   '8',
#   '7',
#   '1',
#   '16',
#   '12980',
#   '72'],
#  ['95',
#   'Ponte di Legno-Passo \u200bTonale-\u200bPresena Glacier-\u200bTemù-Pontedilegno-Tonale-',
#   'Italy',
#   '3016',
#   '1121',
#   '42',
#   '10',
#   '40',
#   '9',
#   '59',
#   'Yes',
#   'Yes',
#   '7',
#   '19',
#   '4',
#   '30',
#   '49825',
#   '0'],
#  ['96',
#   'Eggli-\u200bLa Videmanette-Gstaad-\u200bSaanen-\u200bRougemont',
#   'Switzerland',
#   '2151',
#   '992',
#   '54',
#   '35',
#   '17',
#   '5',
#   '58',
#   'No',
#   'No',
#   '8',
#   '4',
#   '5',
#   '17',
#   '15363',
#   '0'],
#  ['97',
#   'Anzère',
#   'Switzerland',
#   '2420',
#   '1500',
#   '46',
#   '12',
#   '37',
#   '9',
#   '58',
#   'Yes',
#   'No',
#   '10',
#   '3',
#   '1',
#   '14',
#   '12462',
#   '120'],
#  ['98',
#   'Borovets',
#   'Bulgaria',
#   '2560',
#   '1300',
#   '28',
#   '24',
#   '29',
#   '5',
#   '58',
#   'Yes',
#   'Yes',
#   '8',
#   '4',
#   '2',
#   '14',
#   '15800',
#   '160'],
#  ['99',
#   'Font-Romeu-\u200bBolquère Pyrénées 2000',
#   'France',
#   '2213',
#   '1650',
#   '38',
#   '30',
#   '19',
#   '9',
#   '58',
#   'Yes',
#   'No',
#   '15',
#   '8',
#   '1',
#   '24',
#   '27378',
#   '535'],
#  ['100',
#   'Oppdal',
#   'Norway',
#   '1300',
#   '585',
#   '44',
#   '40',
#   '7',
#   '9',
#   '56',
#   'No',
#   'No',
#   '1',
#   '0',
#   '0',
#   '1',
#   '0',
#   '0'],
#  ['101',
#   'Brévent-\u200bFlégère-Chamonix-',
#   'France',
#   '2525',
#   '1030',
#   '51',
#   '11',
#   '25',
#   '20',
#   '56',
#   'Yes',
#   'No',
#   '6',
#   '8',
#   '5',
#   '19',
#   '26734',
#   '0'],
#  ['102',
#   'Les Houches-\u200bSaint-Gervais-Prarion-\u200bBellevue-Chamonix-',
#   'France',
#   '1000',
#   '584',
#   '43',
#   '25',
#   '25',
#   '5',
#   '55',
#   'Yes',
#   'No',
#   '5',
#   '8',
#   '3',
#   '16',
#   '19859',
#   '133'],
#  ['103',
#   'Ylläs',
#   'Finland',
#   '718',
#   '200',
#   '42',
#   '21',
#   '28',
#   '6',
#   '55',
#   'Yes',
#   'Yes',
#   '27',
#   '1',
#   '1',
#   '29',
#   '28284',
#   '36'],
#  ['104',
#   'Belvedere-\u200bCol Rodella-\u200bCiampac-\u200bBuffaure-Canazei-\u200bCampitello-\u200bAlba-\u200bPozza di Fassa',
#   'Italy',
#   '2428',
#   '1320',
#   '48',
#   '7',
#   '40',
#   '7',
#   '55',
#   'Yes',
#   'Yes',
#   '11',
#   '18',
#   '10',
#   '39',
#   '56216',
#   '0'],
#  ['105',
#   'Lauchernalp-Lötschental',
#   'Switzerland',
#   '3111',
#   '1419',
#   '48',
#   '20',
#   '17',
#   '18',
#   '55',
#   'Yes',
#   'No',
#   '2',
#   '2',
#   '2',
#   '6',
#   '6800',
#   '28'],
#  ['106',
#   'Grossglockner Heiligenblut',
#   'Austria',
#   '2989',
#   '1301',
#   '44',
#   '20',
#   '34',
#   '1',
#   '55',
#   'No',
#   'No',
#   '8',
#   '1',
#   '4',
#   '13',
#   '12500',
#   '60'],
#  ['107',
#   'Brandnertal-Brand-\u200bBürserberg',
#   'Austria',
#   '2000',
#   '904',
#   '46',
#   '22',
#   '30',
#   '3',
#   '55',
#   'Yes',
#   'Yes',
#   '6',
#   '6',
#   '3',
#   '15',
#   '18963',
#   '82'],
#  ['108',
#   'Alpe du Grand-Serre-La Morte',
#   'France',
#   '2184',
#   '1367',
#   '27',
#   '36',
#   '17',
#   '2',
#   '55',
#   'Yes',
#   'No',
#   '12',
#   '3',
#   '0',
#   '15',
#   '13486',
#   '0'],
#  ['109',
#   'Les Angles',
#   'France',
#   '2376',
#   '1600',
#   '38',
#   '22',
#   '23',
#   '10',
#   '55',
#   'Yes',
#   'Yes',
#   '15',
#   '4',
#   '1',
#   '20',
#   '21787',
#   '363'],
#  ['110',
#   'Kopaonik',
#   'Serbia',
#   '2017',
#   '1057',
#   '30',
#   '30',
#   '19',
#   '6',
#   '55',
#   'Yes',
#   'Yes',
#   '14',
#   '13',
#   '0',
#   '27',
#   '35052',
#   '315'],
#  ['111',
#   'Aussois',
#   'France',
#   '2750',
#   '1500',
#   '29',
#   '30',
#   '22',
#   '3',
#   '55',
#   'Yes',
#   'No',
#   '4',
#   '4',
#   '0',
#   '8',
#   '9228',
#   '130'],
#  ['112',
#   'First-Grindelwald',
#   'Switzerland',
#   '2501',
#   '1050',
#   '55',
#   '30',
#   '15',
#   '8',
#   '53',
#   'Yes',
#   'No',
#   '3',
#   '3',
#   '3',
#   '9',
#   '12720',
#   '38'],
#  ['113',
#   'Sörenberg-Rothorn-\u200bDorf',
#   'Switzerland',
#   '2350',
#   '1110',
#   '44',
#   '30',
#   '15',
#   '8',
#   '53',
#   'Yes',
#   'Yes',
#   '12',
#   '3',
#   '2',
#   '17',
#   '20930',
#   '0'],
#  ['114',
#   'Riserva Bianca-Limone Piemonte',
#   'Italy',
#   '2060',
#   '1046',
#   '34',
#   '11',
#   '35',
#   '5',
#   '52',
#   'No',
#   'No',
#   '5',
#   '11',
#   '1',
#   '17',
#   '20655',
#   '0'],
#  ['115',
#   'Gitschberg Jochtal',
#   'Italy',
#   '1354',
#   '772',
#   '46',
#   '17',
#   '25',
#   '9',
#   '51',
#   'Yes',
#   'No',
#   '14',
#   '4',
#   '6',
#   '24',
#   '23617',
#   '90'],
#  ['116',
#   'Schilthorn-Mürren-\u200bLauterbrunnen',
#   'Switzerland',
#   '2970',
#   '796',
#   '55',
#   '19',
#   '23',
#   '9',
#   '51',
#   'Yes',
#   'No',
#   '3',
#   '7',
#   '6',
#   '16',
#   '13852',
#   '38'],
#  ['117',
#   'Pila',
#   'Italy',
#   '1540',
#   '570',
#   '42',
#   '8',
#   '35',
#   '6',
#   '50',
#   'Yes',
#   'No',
#   '5',
#   '8',
#   '4',
#   '17',
#   '22154',
#   '480'],
#  ['118',
#   'Brigels-\u200bWaltensburg-\u200bAndiast',
#   'Switzerland',
#   '2418',
#   '1110',
#   '49',
#   '13',
#   '33',
#   '3',
#   '50',
#   'Yes',
#   'Yes',
#   '9',
#   '4',
#   '0',
#   '13',
#   '10030',
#   '100'],
#  ['119',
#   'Aprica',
#   'Italy',
#   '2270',
#   '1162',
#   '38',
#   '28',
#   '14',
#   '7',
#   '50',
#   'Yes',
#   'No',
#   '10',
#   '4',
#   '2',
#   '16',
#   '13965',
#   '0'],
#  ['120',
#   'Bormio-Cima Bianca',
#   'Italy',
#   '3012',
#   '1225',
#   '40',
#   '14',
#   '34',
#   '2',
#   '50',
#   'Yes',
#   'Yes',
#   '8',
#   '5',
#   '2',
#   '15',
#   '17630',
#   '240'],
#  ['121',
#   'Sedrun-Oberalp',
#   'Switzerland',
#   '2300',
#   '1500',
#   '53',
#   '10',
#   '35',
#   '5',
#   '50',
#   'Yes',
#   'No',
#   '7',
#   '5',
#   '0',
#   '12',
#   '12100',
#   '0'],
#  ['122',
#   'Grosseck-\u200bSpeiereck-Mauterndorf-\u200bSt. Michael',
#   'Austria',
#   '2400',
#   '1095',
#   '41',
#   '26',
#   '17',
#   '7',
#   '50',
#   'No',
#   'Yes',
#   '6',
#   '4',
#   '2',
#   '12',
#   '14286',
#   '150'],
#  ['123',
#   'Hirmentaz-\u200bLes Habères-Bellevaux-\u200bHabère-Poche',
#   'France',
#   '1610',
#   '923',
#   '24',
#   '30',
#   '17',
#   '3',
#   '50',
#   'Yes',
#   'No',
#   '27',
#   '6',
#   '0',
#   '33',
#   '29480',
#   '0'],
#  ['124',
#   'Pragelato',
#   'Italy',
#   '2700',
#   '1335',
#   '0',
#   '14',
#   '32',
#   '4',
#   '50',
#   'No',
#   'No',
#   '4',
#   '1',
#   '0',
#   '5',
#   '3660',
#   '0'],
#  ['125',
#   'Porté Puymorens',
#   'France',
#   '2471',
#   '1600',
#   '30',
#   '21',
#   '20',
#   '9',
#   '50',
#   'Yes',
#   'No',
#   '5',
#   '4',
#   '0',
#   '9',
#   '7380',
#   '70'],
#  ['126',
#   'Mythenregion',
#   'Switzerland',
#   '1070',
#   '573',
#   '39',
#   '18',
#   '31',
#   '1',
#   '50',
#   'Yes',
#   'No',
#   '11',
#   '0',
#   '4',
#   '15',
#   '12592',
#   '55'],
#  ['127',
#   'Candanchú',
#   'Spain',
#   '2236',
#   '1514',
#   '41',
#   '15',
#   '18',
#   '15',
#   '50',
#   'No',
#   'No',
#   '19',
#   '6',
#   '0',
#   '25',
#   '19650',
#   '0'],
#  ['128',
#   'Zugspitze',
#   'Germany',
#   '2000',
#   '700',
#   '45',
#   '7',
#   '13',
#   '0',
#   '20',
#   'No',
#   'No',
#   '4',
#   '2',
#   '4',
#   '10',
#   '13150',
#   '0'],
#  ['129',
#   'Lindvallen-\u200bHögfjället-Sälen-',
#   'Sweden',
#   '887',
#   '579',
#   '41',
#   '22',
#   '17',
#   '3',
#   '42',
#   'Yes',
#   'Yes',
#   '49',
#   '4',
#   '0',
#   '53',
#   '50505',
#   '0'],
#  ['130',
#   'Jasná Nízke Tatry-Chopok',
#   'Slovakia',
#   '2004',
#   '943',
#   '39',
#   '19',
#   '17',
#   '7',
#   '44',
#   'Yes',
#   'Yes',
#   '19',
#   '8',
#   '5',
#   '32',
#   '35225',
#   '527'],
#  ['131',
#   'Tandådalen-\u200bHundfjället-Sälen-',
#   'Sweden',
#   '872',
#   '572',
#   '41',
#   '18',
#   '15',
#   '12',
#   '45',
#   'Yes',
#   'Yes',
#   '42',
#   '4',
#   '0',
#   '46',
#   '42636',
#   '0'],
#  ['132',
#   'Sheregesh-Kemerovo',
#   'Siberia',
#   '1270',
#   '670',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   'No',
#   'No',
#   '3',
#   '5',
#   '4',
#   '12',
#   '19919',
#   '0'],
#  ['133',
#   'Gazprom Mountain Resort-Laura-– Esto-Sadok-Sotschi-',
#   'Southern Russia',
#   '949',
#   '547',
#   '32',
#   '7',
#   '10',
#   '2',
#   '20',
#   'No',
#   'Yes',
#   '6',
#   '6',
#   '6',
#   '18',
#   '27874',
#   '0'],
#  ['134',
#   'Steinplatte-\u200bWinklmoosalm-Waidring-\u200bReit im Winkl',
#   'Austria',
#   '1860',
#   '740',
#   '46',
#   '18',
#   '22',
#   '2',
#   '42',
#   'Yes',
#   'No',
#   '3',
#   '9',
#   '2',
#   '14',
#   '31940',
#   '107'],
#  ['135',
#   'Rigi',
#   'Switzerland',
#   '1315',
#   '439',
#   '44',
#   '4',
#   '4',
#   '0',
#   '9',
#   'No',
#   'No',
#   '4',
#   '0',
#   '3',
#   '7',
#   '6500',
#   '0'],
#  ['136',
#   'Métabief',
#   'France',
#   '1420',
#   '1000',
#   '26',
#   '19',
#   '18',
#   '2',
#   '40',
#   'No',
#   'No',
#   '20',
#   '8',
#   '0',
#   '28',
#   '24745',
#   '0'],
#  ['137',
#   'Latemar-Obereggen-\u200bPampeago-\u200bPredazzo',
#   'Italy',
#   '1540',
#   '1050',
#   '47',
#   '9',
#   '32',
#   '7',
#   '48',
#   'Yes',
#   'Yes',
#   '6',
#   '13',
#   '3',
#   '22',
#   '36540',
#   '200'],
#  ['138',
#   'Mariborsko Pohorje-Maribor',
#   'Slovenia',
#   '1327',
#   '325',
#   '31',
#   '23',
#   '13',
#   '5',
#   '41',
#   'No',
#   'Yes',
#   '16',
#   '5',
#   '1',
#   '22',
#   '23436',
#   '92'],
#  ['139',
#   'Praz de Lys-\u200bSommand-Taninges-\u200bMieussy-',
#   'France',
#   '1966',
#   '1240',
#   '29',
#   '22',
#   '16',
#   '6',
#   '45',
#   'Yes',
#   'No',
#   '18',
#   '6',
#   '0',
#   '24',
#   '26205',
#   '60'],
#  ['140',
#   'Espace Dôle-La Dôle-\u200bLes Tuffes',
#   'France',
#   '1678',
#   '1137',
#   '27',
#   '17',
#   '8',
#   '2',
#   '28',
#   'Yes',
#   'No',
#   '18',
#   '3',
#   '0',
#   '21',
#   '19380',
#   '0'],
#  ['141',
#   'Kreischberg',
#   'Austria',
#   '2118',
#   '868',
#   '44',
#   '17',
#   '16',
#   '9',
#   '42',
#   'Yes',
#   'No',
#   '7',
#   '4',
#   '3',
#   '14',
#   '18808',
#   '110'],
#  ['142',
#   'Garmisch-Classic-Garmisch-Partenkirchen',
#   'Germany',
#   '2050',
#   '732',
#   '43',
#   '12',
#   '18',
#   '10',
#   '40',
#   'Yes',
#   'No',
#   '11',
#   '4',
#   '4',
#   '19',
#   '21090',
#   '0'],
#  ['143',
#   'Aiguille du Midi-Chamonix-',
#   'France',
#   '3842',
#   '1035',
#   '60',
#   '0',
#   '0',
#   '0',
#   '0',
#   'No',
#   'No',
#   '0',
#   '0',
#   '5',
#   '5',
#   '4820',
#   '0'],
#  ['144',
#   'Carezza Ski',
#   'Italy',
#   '2337',
#   '1200',
#   '41',
#   '21',
#   '14',
#   '3',
#   '40',
#   'Yes',
#   'No',
#   '13',
#   '5',
#   '2',
#   '20',
#   '19200',
#   '175'],
#  ['145',
#   'Pizol-Bad Ragaz-\u200bWangs',
#   'Switzerland',
#   '510',
#   '490',
#   '51',
#   '14',
#   '21',
#   '8',
#   '43',
#   'Yes',
#   'Yes',
#   '5',
#   '4',
#   '2',
#   '11',
#   '12786',
#   '62'],
#  ['146',
#   'SuperBesse-Puy de Sancy',
#   'France',
#   '1850',
#   '1300',
#   '32',
#   '30',
#   '9',
#   '4',
#   '43',
#   'Yes',
#   'Yes',
#   '16',
#   '5',
#   '1',
#   '22',
#   '21245',
#   '299'],
#  ['147',
#   'Stöten',
#   'Sweden',
#   '830',
#   '443',
#   '41',
#   '26',
#   '3',
#   '3',
#   '32',
#   'No',
#   'No',
#   '17',
#   '2',
#   '0',
#   '19',
#   '19250',
#   '0'],
#  ['148',
#   'Fellhorn-\u200bKanzelwand-Oberstdorf-\u200bRiezlern',
#   'Austria',
#   '1967',
#   '920',
#   '45',
#   '13',
#   '19',
#   '2',
#   '34',
#   'Yes',
#   'Yes',
#   '7',
#   '6',
#   '4',
#   '17',
#   '22076',
#   '110'],
#  ['149',
#   'Idre Fjäll',
#   'Sweden',
#   '890',
#   '588',
#   '40',
#   '17',
#   '22',
#   '2',
#   '41',
#   'Yes',
#   'Yes',
#   '21',
#   '4',
#   '0',
#   '25',
#   '24760',
#   '0'],
#  ['150',
#   'Großglockner Resort Kals-Matrei',
#   'Austria',
#   '2422',
#   '933',
#   '47',
#   '8',
#   '22',
#   '6',
#   '37',
#   'Yes',
#   'No',
#   '9',
#   '5',
#   '3',
#   '17',
#   '18276',
#   '0'],
#  ['151',
#   'Pamporovo',
#   'Bulgaria',
#   '1926',
#   '1620',
#   '28',
#   '17',
#   '6',
#   '5',
#   '29',
#   'Yes',
#   'Yes',
#   '6',
#   '7',
#   '0',
#   '13',
#   '14266',
#   '130'],
#  ['152',
#   'Abetone-\u200bVal di Luce',
#   'Italy',
#   '1892',
#   '1240',
#   '30',
#   '14',
#   '28',
#   '1',
#   '44',
#   'Yes',
#   'No',
#   '6',
#   '10',
#   '1',
#   '17',
#   '24056',
#   '110'],
#  ['153',
#   'Gerlitzen',
#   'Austria',
#   '1000',
#   '520',
#   '45',
#   '10',
#   '27',
#   '3',
#   '41',
#   'Yes',
#   'No',
#   '10',
#   '7',
#   '1',
#   '18',
#   '22220',
#   '120'],
#  ['154',
#   'Paganella-Andalo',
#   'Italy',
#   '2125',
#   '1030',
#   '40',
#   '9',
#   '22',
#   '1',
#   '33',
#   'Yes',
#   'Yes',
#   '4',
#   '12',
#   '2',
#   '18',
#   '23996',
#   '0'],
#  ['155',
#   'Melchsee-Frutt-Kerns-',
#   'Switzerland',
#   '2255',
#   '1080',
#   '44',
#   '20',
#   '6',
#   '10',
#   '36',
#   'Yes',
#   'Yes',
#   '5',
#   '4',
#   '2',
#   '11',
#   '14150',
#   '110'],
#  ['156',
#   'Vall de Núria',
#   'Spain',
#   '1964',
#   '912',
#   '30',
#   '4',
#   '2',
#   '1',
#   '7',
#   'No',
#   'No',
#   '3',
#   '1',
#   '2',
#   '6',
#   '4840',
#   '0'],
#  ['157',
#   'Arêches-Beaufort-',
#   'France',
#   '2300',
#   '1050',
#   '29',
#   '15',
#   '20',
#   '15',
#   '50',
#   'Yes',
#   'No',
#   '9',
#   '5',
#   '0',
#   '14',
#   '14462',
#   '45'],
#  ['158',
#   'Špindlerův Mlýn',
#   'Czech Republic',
#   '1235',
#   '702',
#   '34',
#   '8',
#   '13',
#   '2',
#   '24',
#   'Yes',
#   'Yes',
#   '17',
#   '6',
#   '0',
#   '23',
#   '21638',
#   '0'],
#  ['159',
#   'Les Mosses-\u200bLa Lécherette',
#   'Switzerland',
#   '1870',
#   '1445',
#   '31',
#   '10',
#   '30',
#   '0',
#   '40',
#   'No',
#   'No',
#   '14',
#   '0',
#   '0',
#   '14',
#   '10540',
#   '0'],
#  ['160',
#   'Cimone-Montecreto-\u200bSestola-\u200bLe Polle',
#   'Italy',
#   '1976',
#   '900',
#   '35',
#   '15',
#   '25',
#   '10',
#   '50',
#   'Yes',
#   'No',
#   '6',
#   '13',
#   '1',
#   '20',
#   '23746',
#   '0'],
#  ['161',
#   'Luchon Superbagnères',
#   'France',
#   '1440',
#   '635',
#   '34',
#   '16',
#   '10',
#   '6',
#   '32',
#   'Yes',
#   'No',
#   '7',
#   '5',
#   '1',
#   '13',
#   '15965',
#   '180'],
#  ['162',
#   'Lélex-\u200bCrozet',
#   'France',
#   '900',
#   '640',
#   '28',
#   '16',
#   '7',
#   '4',
#   '28',
#   'Yes',
#   'No',
#   '15',
#   '2',
#   '2',
#   '19',
#   '16750',
#   '120'],
#  ['163',
#   'Alpika Service',
#   'Southern Russia',
#   '2228',
#   '535',
#   '0',
#   '10',
#   '10',
#   '5',
#   '25',
#   'No',
#   'No',
#   '1',
#   '1',
#   '7',
#   '9',
#   '18120',
#   '0'],
#  ['164',
#   'Sinaia',
#   'Romania',
#   '880',
#   '834',
#   '32',
#   '3',
#   '11',
#   '4',
#   '20',
#   'No',
#   'No',
#   '2',
#   '3',
#   '4',
#   '9',
#   '9864',
#   '0'],
#  ['165',
#   'Gourette-Eaux Bonnes-',
#   'France',
#   '2450',
#   '1350',
#   '38',
#   '18',
#   '13',
#   '4',
#   '35',
#   'Yes',
#   'No',
#   '4',
#   '5',
#   '3',
#   '12',
#   '19660',
#   '158'],
#  ['166',
#   'Rauriser Hochalmbahnen-Rauris',
#   'Austria',
#   '2175',
#   '940',
#   '43',
#   '15',
#   '12',
#   '5',
#   '32',
#   'Yes',
#   'No',
#   '6',
#   '1',
#   '3',
#   '10',
#   '11927',
#   '35'],
#  ['167',
#   'Hoch-Ybrig-Unteriberg-\u200bOberiberg',
#   'Switzerland',
#   '1850',
#   '1035',
#   '46',
#   '15',
#   '30',
#   '5',
#   '50',
#   'Yes',
#   'No',
#   '8',
#   '5',
#   '1',
#   '14',
#   '16650',
#   '0'],
#  ['168',
#   'Meran 2000',
#   'Italy',
#   '1609',
#   '648',
#   '39',
#   '12',
#   '25',
#   '3',
#   '40',
#   'Yes',
#   'No',
#   '3',
#   '5',
#   '2',
#   '10',
#   '9478',
#   '0'],
#  ['169',
#   'Nätschen-Andermatt',
#   'Switzerland',
#   '2344',
#   '1444',
#   '44',
#   '8',
#   '5',
#   '8',
#   '21',
#   'No',
#   'No',
#   '1',
#   '4',
#   '2',
#   '7',
#   '13600',
#   '0'],
#  ['170',
#   'Albiez-Montrond',
#   'France',
#   '2200',
#   '1500',
#   '25',
#   '25',
#   '7',
#   '3',
#   '35',
#   'No',
#   'No',
#   '8',
#   '5',
#   '0',
#   '13',
#   '10432',
#   '0'],
#  ['171',
#   'Tarvisio-Monte Lussari',
#   'Italy',
#   '1752',
#   '754',
#   '35',
#   '9',
#   '11',
#   '5',
#   '25',
#   'Yes',
#   'Yes',
#   '5',
#   '8',
#   '2',
#   '15',
#   '17354',
#   '0'],
#  ['172',
#   'Mount Parnassos-Fterolakka-\u200bKellaria',
#   'Greece',
#   '2300',
#   '1600',
#   '30',
#   '18',
#   '15',
#   '3',
#   '36',
#   'No',
#   'No',
#   '9',
#   '3',
#   '5',
#   '17',
#   '20052',
#   '0'],
#  ['173',
#   'Moelltal Glacier-Mölltaler Gletscher-',
#   'Austria',
#   '2108',
#   '1222',
#   '47',
#   '5',
#   '7',
#   '4',
#   '17',
#   'Yes',
#   'No',
#   '2',
#   '5',
#   '2',
#   '9',
#   '15610',
#   '45'],
#  ['174',
#   'Wendelstein-Brannenburg-\u200bOsterhofen',
#   'Germany',
#   '1723',
#   '791',
#   '35',
#   '0',
#   '7',
#   '4',
#   '11',
#   'No',
#   'No',
#   '2',
#   '0',
#   '2',
#   '4',
#   '3250',
#   '0'],
#  ['175',
#   'Glenshee',
#   'United Kingdom',
#   '900',
#   '650',
#   '33',
#   '24',
#   '10',
#   '2',
#   '36',
#   'No',
#   'No',
#   '18',
#   '3',
#   '0',
#   '21',
#   '16255',
#   '6'],
#  ['176',
#   "Sulden am Ortler-Solda all'Ortles-",
#   'Italy',
#   '3250',
#   '1900',
#   '41',
#   '17',
#   '13',
#   '14',
#   '44',
#   'Yes',
#   'Yes',
#   '4',
#   '6',
#   '3',
#   '13',
#   '15418',
#   '0'],
#  ['177',
#   'Poiana Brașov',
#   'Romania',
#   '1799',
#   '1021',
#   '32',
#   '5',
#   '2',
#   '5',
#   '13',
#   'No',
#   'Yes',
#   '5',
#   '2',
#   '3',
#   '10',
#   '11038',
#   '145'],
#  ['178',
#   'Hinterstoder-Höss',
#   'Austria',
#   '2000',
#   '600',
#   '44',
#   '12',
#   '18',
#   '10',
#   '40',
#   'Yes',
#   'No',
#   '15',
#   '2',
#   '2',
#   '19',
#   '18464',
#   '267'],
#  ['179',
#   'St. Jean Montclar',
#   'France',
#   '2500',
#   '1350',
#   '28',
#   '25',
#   '20',
#   '5',
#   '50',
#   'No',
#   'No',
#   '10',
#   '4',
#   '0',
#   '14',
#   '13320',
#   '0'],
#  ['180',
#   'Port del Comte',
#   'Spain',
#   '2310',
#   '1745',
#   '33',
#   '20',
#   '15',
#   '5',
#   '40',
#   'No',
#   'No',
#   '11',
#   '5',
#   '0',
#   '16',
#   '13750',
#   '0'],
#  ['181',
#   'Tänndalen',
#   'Sweden',
#   '1038',
#   '743',
#   '41',
#   '20',
#   '15',
#   '3',
#   '38',
#   'No',
#   'No',
#   '15',
#   '2',
#   '0',
#   '17',
#   '19270',
#   '0'],
#  ['182',
#   'Feldberg-Seebuck-\u200bGrafenmatt-\u200bFahl',
#   'Germany',
#   '1448',
#   '888',
#   '35',
#   '7',
#   '14',
#   '5',
#   '26',
#   'Yes',
#   'No',
#   '9',
#   '5',
#   '0',
#   '14',
#   '17624',
#   '0'],
#  ['183',
#   'Pitztal Glacier-Pitztaler Gletscher-',
#   'Austria',
#   '2685',
#   '1740',
#   '48',
#   '3',
#   '16',
#   '0',
#   '20',
#   'Yes',
#   'No',
#   '3',
#   '1',
#   '3',
#   '7',
#   '10935',
#   '0'],
#  ['184',
#   'Tauplitz-Bad Mitterndorf',
#   'Austria',
#   '896',
#   '812',
#   '41',
#   '18',
#   '18',
#   '6',
#   '42',
#   'No',
#   'No',
#   '14',
#   '4',
#   '1',
#   '19',
#   '18525',
#   '135'],
#  ['185',
#   'Hochoetz-Oetz',
#   'Austria',
#   '1410',
#   '820',
#   '37',
#   '12',
#   '21',
#   '3',
#   '36',
#   'Yes',
#   'No',
#   '7',
#   '6',
#   '2',
#   '15',
#   '17422',
#   '89'],
#  ['186',
#   'Rosshütte-Seefeld',
#   'Austria',
#   '2064',
#   '1230',
#   '44',
#   '10',
#   '9',
#   '1',
#   '20',
#   'Yes',
#   'Yes',
#   '8',
#   '3',
#   '2',
#   '13',
#   '12363',
#   '208'],
#  ['187',
#   'Malbun',
#   'Liechtenstein',
#   '2000',
#   '1600',
#   '42',
#   '11',
#   '9',
#   '3',
#   '23',
#   'Yes',
#   'No',
#   '6',
#   '3',
#   '0',
#   '9',
#   '8800',
#   '16'],
#  ['188',
#   'Špičák',
#   'Czech Republic',
#   '1202',
#   '854',
#   '23',
#   '3',
#   '3',
#   '0',
#   '8',
#   'Yes',
#   'Yes',
#   '11',
#   '1',
#   '0',
#   '12',
#   '7390',
#   '30'],
#  ['189',
#   'Riesneralm-Donnersbachwald',
#   'Austria',
#   '1820',
#   '950',
#   '40',
#   '15',
#   '12',
#   '3',
#   '30',
#   'No',
#   'No',
#   '5',
#   '3',
#   '0',
#   '8',
#   '6880',
#   '137'],
#  ['190',
#   'Berwang-\u200bBichlbach-\u200bRinnen',
#   'Austria',
#   '1743',
#   '1067',
#   '42',
#   '24',
#   '10',
#   '1',
#   '36',
#   'No',
#   'Yes',
#   '11',
#   '3',
#   '1',
#   '15',
#   '15623',
#   '130'],
#  ['191',
#   'Glungezer-Tulfes',
#   'Austria',
#   '2304',
#   '950',
#   '30',
#   '7',
#   '15',
#   '0',
#   '23',
#   'Yes',
#   'No',
#   '6',
#   '2',
#   '0',
#   '8',
#   '7116',
#   '2'],
#  ['192',
#   'Fanningberg',
#   'Austria',
#   '2115',
#   '1497',
#   '41',
#   '11',
#   '5',
#   '7',
#   '24',
#   'Yes',
#   'No',
#   '4',
#   '2',
#   '0',
#   '6',
#   '7162',
#   '36'],
#  ['193',
#   'Turracher Höhe',
#   'Austria',
#   '2205',
#   '1400',
#   '45',
#   '14',
#   '24',
#   '3',
#   '42',
#   'Yes',
#   'Yes',
#   '12',
#   '5',
#   '1',
#   '18',
#   '18268',
#   '220'],
#  ['194',
#   'Indoor ski area Snow Arena-Druskininkai',
#   'Lithuania',
#   '163',
#   '97',
#   '29',
#   '1',
#   '0',
#   '0',
#   '1',
#   'Yes',
#   'Yes',
#   '4',
#   '1',
#   '0',
#   '5',
#   '2800',
#   '16'],
#  ['195',
#   'Niedere-Andelsbuch-\u200bBezau',
#   'Austria',
#   '1715',
#   '655',
#   '31',
#   '5',
#   '4',
#   '1',
#   '10',
#   'No',
#   'No',
#   '5',
#   '2',
#   '1',
#   '8',
#   '6043',
#   '2'],
#  ['196',
#   'Wurzeralm-Spital am Pyhrn',
#   'Austria',
#   '1870',
#   '810',
#   '41',
#   '10',
#   '10',
#   '2',
#   '22',
#   'No',
#   'No',
#   '5',
#   '2',
#   '1',
#   '8',
#   '9048',
#   '57'],
#  ['197',
#   'Präbichl-Vordernberg',
#   'Austria',
#   '1608',
#   '1100',
#   '37',
#   '6',
#   '11',
#   '3',
#   '20',
#   'Yes',
#   'No',
#   '4',
#   '2',
#   '0',
#   '6',
#   '6624',
#   '90'],
#  ['198',
#   'Pfelders-Moos in Passeier-',
#   'Italy',
#   '2502',
#   '1601',
#   '33',
#   '5',
#   '9',
#   '4',
#   '18',
#   'Yes',
#   'Yes',
#   '4',
#   '1',
#   '1',
#   '6',
#   '4300',
#   '35'],
#  ['199',
#   'Mitterdorf-Almberg-– Mitterfirmiansreut',
#   'Germany',
#   '1139',
#   '841',
#   '23',
#   '2',
#   '2',
#   '1',
#   '6',
#   'No',
#   'Yes',
#   '9',
#   '1',
#   '0',
#   '10',
#   '6266',
#   '31'],
#  ['200',
#   'Lavarone',
#   'Italy',
#   '1650',
#   '1150',
#   '36',
#   '19',
#   '5',
#   '2',
#   '27',
#   'No',
#   'No',
#   '9',
#   '6',
#   '0',
#   '15',
#   '12040',
#   '70'],
#  ['201',
#   'Geißkopf-Bischofsmais',
#   'Germany',
#   '1116',
#   '835',
#   '24',
#   '1',
#   '5',
#   '0',
#   '8',
#   'Yes',
#   'Yes',
#   '8',
#   '1',
#   '0',
#   '9',
#   '6950',
#   '16'],
#  ['202',
#   'Donovaly-Park Snow-',
#   'Slovakia',
#   '1361',
#   '914',
#   '26',
#   '5',
#   '5',
#   '0',
#   '11',
#   'Yes',
#   'Yes',
#   '23',
#   '1',
#   '1',
#   '25',
#   '13620',
#   '30'],
#  ['203',
#   'Indoor ski area Snow Dome Bispingen',
#   'Germany',
#   '122',
#   '90',
#   '37',
#   '0',
#   '0',
#   '0',
#   '0',
#   'Yes',
#   'Yes',
#   '2',
#   '1',
#   '0',
#   '3',
#   '3710',
#   '12'],
#  ['204',
#   'Sudelfeld-Bayrischzell',
#   'Germany',
#   '1563',
#   '850',
#   '33',
#   '5',
#   '24',
#   '3',
#   '32',
#   'Yes',
#   'No',
#   '10',
#   '5',
#   '0',
#   '15',
#   '17477',
#   '100'],
#  ['205',
#   'Grüntenlifte-Kranzegg-Rettenberg-',
#   'Germany',
#   '1700',
#   '900',
#   '31',
#   '2',
#   '14',
#   '0',
#   '16',
#   'Yes',
#   'No',
#   '8',
#   '1',
#   '0',
#   '9',
#   '7420',
#   '12'],
#  ['206',
#   'Grebenzen-St. Lambrecht',
#   'Austria',
#   '1870',
#   '1010',
#   '34',
#   '2',
#   '9',
#   '0',
#   '12',
#   'No',
#   'No',
#   '6',
#   '1',
#   '0',
#   '7',
#   '6790',
#   '25'],
#  ['207',
#   'Kirchdorf',
#   'Austria',
#   '780',
#   '640',
#   '30',
#   '3',
#   '2',
#   '0',
#   '5',
#   'No',
#   'No',
#   '3',
#   '1',
#   '0',
#   '4',
#   '3570',
#   '6'],
#  ['208',
#   'Nebelhorn-Oberstdorf',
#   'Germany',
#   '2224',
#   '828',
#   '44',
#   '2',
#   '5',
#   '4',
#   '11',
#   'No',
#   'No',
#   '3',
#   '2',
#   '3',
#   '8',
#   '5990',
#   '30'],
#  ['209',
#   'Lachtal',
#   'Austria',
#   '2222',
#   '1600',
#   '41',
#   '7',
#   '16',
#   '2',
#   '25',
#   'No',
#   'No',
#   '8',
#   '2',
#   '0',
#   '10',
#   '10620',
#   '53'],
#  ['210',
#   'Ramsau am Dachstein-Rittisberg',
#   'Austria',
#   '1636',
#   '1035',
#   '36',
#   '14',
#   '10',
#   '1',
#   '25',
#   'No',
#   'No',
#   '14',
#   '1',
#   '0',
#   '15',
#   '10815',
#   '40'],
#  ['211',
#   'Eibenstock',
#   'Germany',
#   '745',
#   '650',
#   '18',
#   '0',
#   '0',
#   '0',
#   '1',
#   'Yes',
#   'Yes',
#   '2',
#   '1',
#   '0',
#   '3',
#   '1980',
#   '8'],
#  ['212',
#   'Bürchen-\u200bTörbel-Moosalp',
#   'Switzerland',
#   '2550',
#   '1480',
#   '39',
#   '5',
#   '15',
#   '5',
#   '25',
#   'No',
#   'Yes',
#   '8',
#   '1',
#   '0',
#   '9',
#   '7470',
#   '7'],
#  ['213',
#   'Guzet',
#   'France',
#   '2100',
#   '1100',
#   '31',
#   '20',
#   '14',
#   '6',
#   '40',
#   'Yes',
#   'No',
#   '11',
#   '4',
#   '0',
#   '15',
#   '11130',
#   '100'],
#  ['214',
#   'Schetteregg-Egg',
#   'Austria',
#   '1325',
#   '1070',
#   '32',
#   '3',
#   '6',
#   '1',
#   '10',
#   'Yes',
#   'No',
#   '7',
#   '1',
#   '0',
#   '8',
#   '6642',
#   '6'],
#  ['215',
#   'Fichtelberg-Oberwiesenthal',
#   'Germany',
#   '1215',
#   '911',
#   '26',
#   '6',
#   '6',
#   '2',
#   '15',
#   'Yes',
#   'Yes',
#   '6',
#   '2',
#   '1',
#   '9',
#   '7384',
#   '141'],
#  ['216',
#   'Bellwald',
#   'Switzerland',
#   '1600',
#   '1204',
#   '45',
#   '9',
#   '21',
#   '6',
#   '36',
#   'Yes',
#   'No',
#   '3',
#   '2',
#   '1',
#   '6',
#   '4620',
#   '26'],
#  ['217',
#   'Dry slopes Dayz Søhøjlandets Skicenter',
#   'Denmark',
#   '100',
#   '80',
#   '36',
#   '0',
#   '0',
#   '0',
#   '0',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['218',
#   'Indoor ski area Skidome Denmark – Randers (planned)',
#   'Denmark',
#   '120',
#   '10',
#   '0',
#   '1',
#   '1',
#   '1',
#   '3',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['219',
#   'Dry slopes Indoorski – Rødovre',
#   'Denmark',
#   '53',
#   '50',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['220',
#   'Dry slopes Ski Arena – Aarhus',
#   'Denmark',
#   '23',
#   '20',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['221',
#   'Copenhagen (planned)',
#   'Denmark',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['222',
#   'Østerlars (Bornholm)',
#   'Denmark',
#   '110',
#   '72',
#   '18',
#   '0',
#   '0',
#   '0',
#   '0',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1220',
#   '0'],
#  ['223',
#   'Hoch Hylkedal – Kolding',
#   'Denmark',
#   '45',
#   '20',
#   '15',
#   '0',
#   '0',
#   '0',
#   '0',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '600',
#   '0'],
#  ['224',
#   'Klewenalp-\u200bStockhütte-Beckenried-\u200bEmmetten',
#   'Switzerland',
#   '1200',
#   '436',
#   '45',
#   '15',
#   '25',
#   '0',
#   '40',
#   'No',
#   'No',
#   '9',
#   '3',
#   '2',
#   '14',
#   '13394',
#   '0'],
#  ['225',
#   'Schöneck-Skiwelt-',
#   'Germany',
#   '760',
#   '620',
#   '20',
#   '1',
#   '1',
#   '0',
#   '3',
#   'Yes',
#   'Yes',
#   '5',
#   '1',
#   '0',
#   '6',
#   '4324',
#   '16'],
#  ['226',
#   'Indoor ski area SnowWorld Landgraaf',
#   'Netherlands',
#   '210',
#   '150',
#   '42',
#   '0',
#   '0',
#   '0',
#   '1',
#   'Yes',
#   'Yes',
#   '10',
#   '9',
#   '0',
#   '19',
#   '5231',
#   '4'],
#  ['227',
#   'Štrbské Pleso',
#   'Slovakia',
#   '1840',
#   '1376',
#   '35',
#   '2',
#   '5',
#   '0',
#   '8',
#   'Yes',
#   'No',
#   '5',
#   '3',
#   '0',
#   '8',
#   '7700',
#   '52'],
#  ['228',
#   'Gaissau-Hintersee',
#   'Austria',
#   '1567',
#   '750',
#   '35',
#   '23',
#   '10',
#   '0',
#   '34',
#   'Yes',
#   'No',
#   '6',
#   '3',
#   '0',
#   '9',
#   '10110',
#   '0'],
#  ['229',
#   'Kellerjoch-Schwaz',
#   'Austria',
#   '857',
#   '545',
#   '29',
#   '5',
#   '2',
#   '2',
#   '10',
#   'No',
#   'No',
#   '4',
#   '2',
#   '0',
#   '6',
#   '3786',
#   '5'],
#  ['230',
#   'Hochrindl-Sirnitz',
#   'Austria',
#   '1886',
#   '1540',
#   '32',
#   '5',
#   '11',
#   '3',
#   '20',
#   'Yes',
#   'Yes',
#   '11',
#   '1',
#   '0',
#   '12',
#   '7350',
#   '30'],
#  ['231',
#   'La Bresse-Hohneck',
#   'France',
#   '1350',
#   '872',
#   '29',
#   '13',
#   '7',
#   '1',
#   '21',
#   'No',
#   'Yes',
#   '12',
#   '6',
#   '0',
#   '18',
#   '21515',
#   '300'],
#  ['232',
#   'Silbersattel-Steinach',
#   'Germany',
#   '842',
#   '590',
#   '19',
#   '2',
#   '1',
#   '0',
#   '4',
#   'Yes',
#   'No',
#   '3',
#   '1',
#   '0',
#   '4',
#   '3300',
#   '6'],
#  ['233',
#   'Lammeralm-Langenwang',
#   'Austria',
#   '1230',
#   '980',
#   '29',
#   '2',
#   '3',
#   '2',
#   '8',
#   'No',
#   'No',
#   '2',
#   '6',
#   '3',
#   '11',
#   '2800',
#   '24'],
#  ['234',
#   'Kitzbüheler Horn',
#   'Austria',
#   '2000',
#   '800',
#   '40',
#   '6',
#   '9',
#   '2',
#   '17',
#   'Yes',
#   'No',
#   '7',
#   '2',
#   '0',
#   '9',
#   '10110',
#   '55'],
#  ['235',
#   'Myrkdalen',
#   'Norway',
#   '1060',
#   '450',
#   '44',
#   '13',
#   '12',
#   '4',
#   '30',
#   'Yes',
#   'Yes',
#   '2',
#   '4',
#   '3',
#   '9',
#   '10279',
#   '32'],
#  ['236',
#   'Loser-Altaussee',
#   'Austria',
#   '1770',
#   '850',
#   '40',
#   '18',
#   '12',
#   '3',
#   '33',
#   'Yes',
#   'No',
#   '3',
#   '2',
#   '3',
#   '8',
#   '11114',
#   '50'],
#  ['237',
#   'Christlum-Achenkirch',
#   'Austria',
#   '1800',
#   '950',
#   '44',
#   '6',
#   '16',
#   '5',
#   '27',
#   'Yes',
#   'No',
#   '9',
#   '4',
#   '0',
#   '13',
#   '12843',
#   '0'],
#  ['238',
#   'Grasgehren-Bolgengrat',
#   'Germany',
#   '1700',
#   '1400',
#   '25',
#   '3',
#   '8',
#   '0',
#   '11',
#   'Yes',
#   'No',
#   '5',
#   '1',
#   '0',
#   '6',
#   '5140',
#   '10'],
#  ['239',
#   'Götschen-Bischofswiesen',
#   'Germany',
#   '1307',
#   '880',
#   '25',
#   '2',
#   '1',
#   '4',
#   '8',
#   'No',
#   'Yes',
#   '2',
#   '1',
#   '0',
#   '3',
#   '4000',
#   '35'],
#  ['240',
#   'Torrent-Leukerbad',
#   'Switzerland',
#   '2610',
#   '1411',
#   '46',
#   '3',
#   '26',
#   '16',
#   '47',
#   'Yes',
#   'No',
#   '8',
#   '1',
#   '5',
#   '14',
#   '11390',
#   '40'],
#  ['241',
#   'Monte Popolo-Eben im Pongau',
#   'Austria',
#   '1612',
#   '862',
#   '36',
#   '4',
#   '2',
#   '0',
#   '6',
#   'Yes',
#   'No',
#   '2',
#   '2',
#   '0',
#   '4',
#   '4550',
#   '55'],
#  ['242',
#   'Jochgrimm-Passo Oclini-',
#   'Italy',
#   '2250',
#   '1850',
#   '17',
#   '4',
#   '2',
#   '1',
#   '7',
#   'No',
#   'No',
#   '0',
#   '3',
#   '5',
#   '8',
#   '3540',
#   '20'],
#  ['243',
#   'Alpe Lusia-Moena-\u200bBellamonte',
#   'Italy',
#   '2340',
#   '1370',
#   '47',
#   '12',
#   '10',
#   '4',
#   '27',
#   'Yes',
#   'No',
#   '3',
#   '3',
#   '4',
#   '10',
#   '16280',
#   '0'],
#  ['244',
#   'Unternberg-Ruhpolding-',
#   'Germany',
#   '1417',
#   '710',
#   '20',
#   '1',
#   '1',
#   '0',
#   '2',
#   'No',
#   'Yes',
#   '3',
#   '1',
#   '0',
#   '4',
#   '3350',
#   '15'],
#  ['245',
#   'Diavolezza-\u200bLagalb',
#   'Switzerland',
#   '3006',
#   '2091',
#   '59',
#   '0',
#   '21',
#   '10',
#   '31',
#   'No',
#   'No',
#   '9',
#   '2',
#   '0',
#   '11',
#   '3970',
#   '20'],
#  ['246',
#   'Kubínska hoľa',
#   'Slovakia',
#   '1396',
#   '720',
#   '26',
#   '2',
#   '10',
#   '2',
#   '14',
#   'Yes',
#   'No',
#   '2',
#   '1',
#   '2',
#   '5',
#   '11480',
#   '60'],
#  ['247',
#   'Gålå',
#   'Norway',
#   '1148',
#   '800',
#   '43',
#   '13',
#   '5',
#   '1',
#   '19',
#   'Yes',
#   'Yes',
#   '7',
#   '1',
#   '0',
#   '8',
#   '7600',
#   '50'],
#  ['248',
#   'Kvitfjell',
#   'Norway',
#   '1039',
#   '185',
#   '45',
#   '19',
#   '10',
#   '5',
#   '34',
#   'Yes',
#   'Yes',
#   '14',
#   '2',
#   '0',
#   '16',
#   '17952',
#   '90'],
#  ['249',
#   'Molines-en-Queyras-\u200bSaint-Véran',
#   'France',
#   '2800',
#   '1750',
#   '29',
#   '20',
#   '12',
#   '1',
#   '33',
#   'No',
#   'No',
#   '9',
#   '5',
#   '0',
#   '14',
#   '12290',
#   '0'],
#  ['250',
#   'Tatranská Lomnica',
#   'Slovakia',
#   '2190',
#   '888',
#   '35',
#   '5',
#   '5',
#   '1',
#   '11',
#   'No',
#   'No',
#   '3',
#   '1',
#   '0',
#   '4',
#   '12480',
#   '216'],
#  ['251',
#   'Kanin-Sella Nevea-\u200bBovec',
#   'Slovenia',
#   '1103',
#   '460',
#   '35',
#   '4',
#   '6',
#   '0',
#   '10',
#   'No',
#   'No',
#   '3',
#   '4',
#   '4',
#   '11',
#   '11670',
#   '0'],
#  ['252',
#   'Postwiesen Skidorf-Neuastenberg',
#   'Germany',
#   '730',
#   '605',
#   '26',
#   '3',
#   '3',
#   '1',
#   '8',
#   'Yes',
#   'Yes',
#   '8',
#   '1',
#   '0',
#   '9',
#   '6762',
#   '23'],
#  ['253',
#   'Oberjoch-Bad Hindelang-– Iseler',
#   'Germany',
#   '1559',
#   '1130',
#   '38',
#   '6',
#   '24',
#   '2',
#   '32',
#   'Yes',
#   'Yes',
#   '2',
#   '4',
#   '0',
#   '6',
#   '12388',
#   '70'],
#  ['254',
#   'Mönichkirchen-\u200bMariensee',
#   'Austria',
#   '1450',
#   '870',
#   '35',
#   '5',
#   '6',
#   '2',
#   '13',
#   'Yes',
#   'No',
#   '3',
#   '3',
#   '0',
#   '6',
#   '6741',
#   '80'],
#  ['255',
#   'Grächen',
#   'Switzerland',
#   '2864',
#   '1619',
#   '48',
#   '9',
#   '31',
#   '2',
#   '42',
#   'No',
#   'No',
#   '9',
#   '5',
#   '1',
#   '15',
#   '13860',
#   '0'],
#  ['256',
#   'Puigmal',
#   'France',
#   '2700',
#   '1830',
#   '0',
#   '9',
#   '15',
#   '7',
#   '32',
#   'No',
#   'No',
#   '11',
#   '2',
#   '0',
#   '13',
#   '11865',
#   '0'],
#  ['257',
#   'Kranzberg-Mittenwald',
#   'Germany',
#   '1350',
#   '980',
#   '29',
#   '6',
#   '7',
#   '2',
#   '15',
#   'Yes',
#   'Yes',
#   '9',
#   '1',
#   '0',
#   '10',
#   '5850',
#   '8'],
#  ['258',
#   'Wetterstein lifts-Wettersteinbahnen-– Ehrwald',
#   'Austria',
#   '1530',
#   '1000',
#   '43',
#   '15',
#   '5',
#   '3',
#   '23',
#   'Yes',
#   'No',
#   '6',
#   '4',
#   '0',
#   '10',
#   '5425',
#   '33'],
#  ['259',
#   'Stuhleck-Spital am Semmering',
#   'Austria',
#   '1774',
#   '777',
#   '42',
#   '18',
#   '6',
#   '0',
#   '24',
#   'Yes',
#   'Yes',
#   '7',
#   '2',
#   '0',
#   '9',
#   '14400',
#   '240'],
#  ['260',
#   'Glacier 3000 / Les Diablerets',
#   'Switzerland',
#   '3016',
#   '1343',
#   '54',
#   '9',
#   '3',
#   '12',
#   '25',
#   'Yes',
#   'No',
#   '4',
#   '3',
#   '3',
#   '10',
#   '10260',
#   '0'],
#  ['261',
#   'Rossfeld - Berchtesgaden - Oberau',
#   'Germany',
#   '1554',
#   '1300',
#   '20',
#   '7',
#   '1',
#   '0',
#   '8',
#   'Yes',
#   'Yes',
#   '4',
#   '0',
#   '0',
#   '4',
#   '3229',
#   '0'],
#  ['262',
#   'Les Arcs /\u200b Peisey-Vallandry (Paradiski)',
#   'France',
#   '3226',
#   '1200',
#   '50',
#   '104',
#   '70',
#   '26',
#   '200',
#   'Yes',
#   'Yes',
#   '17',
#   '27',
#   '8',
#   '52',
#   '82641',
#   '793'],
#  ['263',
#   "Tignes - \u200bVal d'Isère",
#   'France',
#   '3456',
#   '1550',
#   '56',
#   '170',
#   '78',
#   '52',
#   '300',
#   'Yes',
#   'No',
#   '33',
#   '42',
#   '11',
#   '86',
#   '145461',
#   '848'],
#  ['264',
#   'Livigno – Carosello/\u200bMottolino',
#   'Italy',
#   '2798',
#   '1816',
#   '46',
#   '30',
#   '65',
#   '20',
#   '115',
#   'Yes',
#   'Yes',
#   '25',
#   '13',
#   '6',
#   '44',
#   '50850',
#   '0'],
#  ['265',
#   'Courchevel (Les 3 Vallées)',
#   'France',
#   '3230',
#   '1110',
#   '61',
#   '312',
#   '216',
#   '72',
#   '600',
#   'Yes',
#   'Yes',
#   '62',
#   '63',
#   '40',
#   '165',
#   '250860',
#   '2383'],
#  ['266',
#   'Les Gets (Les Portes du Soleil)',
#   'France',
#   '2466',
#   '1000',
#   '51',
#   '310',
#   '210',
#   '60',
#   '580',
#   'Yes',
#   'Yes',
#   '89',
#   '74',
#   '11',
#   '174',
#   '252280',
#   '1074'],
#  ['267',
#   'Avoriaz (Les Portes du Soleil)',
#   'France',
#   '2466',
#   '1000',
#   '51',
#   '310',
#   '210',
#   '60',
#   '580',
#   'Yes',
#   'Yes',
#   '89',
#   '74',
#   '11',
#   '174',
#   '252280',
#   '1074'],
#  ['268',
#   'Châtel (Les Portes du Soleil)',
#   'France',
#   '2466',
#   '1000',
#   '51',
#   '310',
#   '210',
#   '60',
# ...
#   'Austria',
#   '1900',
#   '800',
#   '52',
#   '52',
#   '41',
#   '19',
#   '112',
#   'Yes',
#   'Yes',
#   '21',
#   '9',
#   '5',
#   '35',
#   '49232',
#   '520'],
#  ['290',
#   'Bonneval sur Arc',
#   'France',
#   '3000',
#   '1850',
#   '28',
#   '13',
#   '11',
#   '1',
#   '25',
#   'No',
#   'No',
#   '8',
#   '3',
#   '0',
#   '11',
#   '8213',
#   '0'],
#  ['291',
#   'Brauneck Lenggries \u200bWegscheid',
#   'Germany',
#   '1712',
#   '700',
#   '35',
#   '8',
#   '22',
#   '4',
#   '34',
#   'No',
#   'Yes',
#   '16',
#   '4',
#   '1',
#   '21',
#   '19100',
#   '0'],
#  ['292',
#   'Brunni - Engelberg',
#   'Switzerland',
#   '2040',
#   '1050',
#   '38',
#   '2',
#   '3',
#   '2',
#   '7',
#   'No',
#   'No',
#   '3',
#   '1',
#   '1',
#   '5',
#   '2577',
#   '0'],
#  ['293',
#   'Madonna di Campiglio-\u200bPinzolo-\u200bFolgàrida-\u200bMarilleva',
#   'Italy',
#   '2504',
#   '770',
#   '50',
#   '60',
#   '68',
#   '22',
#   '150',
#   'Yes',
#   'Yes',
#   '14',
#   '34',
#   '17',
#   '65',
#   '102340',
#   '0'],
#  ['294',
#   'Le Lys - Cauterets',
#   'France',
#   '1360',
#   '932',
#   '37',
#   '21',
#   '12',
#   '3',
#   '36',
#   'Yes',
#   'No',
#   '6',
#   '4',
#   '1',
#   '11',
#   '13038',
#   '0'],
#  ['295',
#   "Pont d'Espagne - Cauterets",
#   'France',
#   '1756',
#   '1516',
#   '35',
#   '3',
#   '1',
#   '0',
#   '4',
#   'No',
#   'No',
#   '2',
#   '1',
#   '1',
#   '4',
#   '4150',
#   '0'],
#  ['296',
#   'Cervinia',
#   'Switzerland',
#   '3899',
#   '1562',
#   '81',
#   '75',
#   '220',
#   '27',
#   '322',
#   'Yes',
#   'No',
#   '21',
#   '22',
#   '20',
#   '63',
#   '93464',
#   '1060'],
#  ['297',
#   'Grands Montets-Argentière (Chamonix)',
#   'France',
#   '3275',
#   '1252',
#   '62',
#   '6',
#   '9',
#   '14',
#   '29',
#   'Yes',
#   'No',
#   '1',
#   '4',
#   '4',
#   '9',
#   '15756',
#   '0'],
#  ['298',
#   'Balme-\u200bLes Autannes-Vallorcine-\u200bLe Tour',
#   'France',
#   '2270',
#   '1453',
#   '51',
#   '13',
#   '16',
#   '0',
#   '29',
#   'Yes',
#   'No',
#   '8',
#   '2',
#   '2',
#   '12',
#   '14860',
#   '0'],
#  ['299',
#   'Crans-Montana',
#   'Switzerland',
#   '1510',
#   '540',
#   '60',
#   '55',
#   '70',
#   '15',
#   '140',
#   'Yes',
#   'No',
#   '12',
#   '6',
#   '5',
#   '23',
#   '29500',
#   '0'],
#  ['300',
#   'Rinerhorn (Davos Klosters)',
#   'Switzerland',
#   '2490',
#   '1454',
#   '48',
#   '10',
#   '22',
#   '8',
#   '40',
#   'Yes',
#   'No',
#   '6',
#   '0',
#   '1',
#   '7',
#   '6900',
#   '14'],
#  ['301',
#   'Jakobshorn (Davos Klosters)',
#   'Switzerland',
#   '2590',
#   '1540',
#   '58',
#   '25',
#   '13',
#   '2',
#   '41',
#   'Yes',
#   'No',
#   '5',
#   '5',
#   '3',
#   '13',
#   '15800',
#   '140'],
#  ['302',
#   'Pischa (Davos Klosters)',
#   'Switzerland',
#   '2483',
#   '1800',
#   '40',
#   '0',
#   '0',
#   '0',
#   '0',
#   'No',
#   'No',
#   '0',
#   '0',
#   '1',
#   '1',
#   '800',
#   '0'],
#  ['303',
#   'Madrisa (Davos Klosters)',
#   'Switzerland',
#   '2611',
#   '1142',
#   '52',
#   '6',
#   '9',
#   '9',
#   '26',
#   'Yes',
#   'No',
#   '7',
#   '2',
#   '1',
#   '10',
#   '6640',
#   '9'],
#  ['304',
#   "Cortina d'Ampezzo",
#   'Italy',
#   '2924',
#   '1224',
#   '52',
#   '45',
#   '55',
#   '20',
#   '120',
#   'Yes',
#   'No',
#   '8',
#   '26',
#   '6',
#   '40',
#   '48089',
#   '130'],
#  ['305',
#   'St. Moritz - Corviglia',
#   'Switzerland',
#   '3057',
#   '1720',
#   '69',
#   '42',
#   '79',
#   '34',
#   '155',
#   'Yes',
#   'No',
#   '11',
#   '12',
#   '5',
#   '28',
#   '31220',
#   '170'],
#  ['306',
#   'Espace Diamant-Les Saisies/\u200bNotre-Dame-de-Bellecombe/\u200bPraz sur Arly/\u200bFlumet/\u200bCrest-Voland',
#   'France',
#   '2069',
#   '1000',
#   '40',
#   '132',
#   '49',
#   '11',
#   '192',
#   'Yes',
#   'Yes',
#   '53',
#   '30',
#   '0',
#   '83',
#   '90852',
#   '472'],
#  ['307',
#   'Fonna Glacier',
#   'Norway',
#   '1460',
#   '1200',
#   '42',
#   '2',
#   '2',
#   '0',
#   '5',
#   'Yes',
#   'No',
#   '1',
#   '0',
#   '0',
#   '1',
#   '1200',
#   '0'],
#  ['308',
#   'Galtür',
#   'Austria',
#   '2300',
#   '1600',
#   '40',
#   '6',
#   '25',
#   '12',
#   '43',
#   'Yes',
#   'Yes',
#   '9',
#   '2',
#   '2',
#   '13',
#   '15442',
#   '133'],
#  ['309',
#   'Glencoe Mountain',
#   'United Kingdom',
#   '1070',
#   '360',
#   '35',
#   '7',
#   '10',
#   '7',
#   '24',
#   'No',
#   'No',
#   '6',
#   '2',
#   '0',
#   '8',
#   '5800',
#   '0'],
#  ['310',
#   'Golm',
#   'Austria',
#   '2110',
#   '650',
#   '48',
#   '13',
#   '12',
#   '1',
#   '26',
#   'No',
#   'No',
#   '4',
#   '4',
#   '3',
#   '11',
#   '16240',
#   '123'],
#  ['311',
#   'Grandvalira – Pas de la Casa/\u200bGrau Roig/\u200bSoldeu/\u200bEl Tarter/\u200bCanillo/\u200bEncamp',
#   'Andorra',
#   '2640',
#   '1710',
#   '47',
#   '100',
#   '77',
#   '33',
#   '210',
#   'Yes',
#   'Yes',
#   '37',
#   '28',
#   '7',
#   '72',
#   '99017',
#   '1032'],
#  ['312',
#   'El Tarter – Pas de la Casa/\u200bGrau Roig/\u200bSoldeu/\u200bCanillo/\u200bEncamp (Grandvalira)',
#   'Andorra',
#   '2640',
#   '1710',
#   '47',
#   '100',
#   '77',
#   '33',
#   '210',
#   'Yes',
#   'Yes',
#   '37',
#   '28',
#   '7',
#   '72',
#   '99017',
#   '1032'],
#  ['313',
#   'Gresse en Vercors',
#   'France',
#   '1751',
#   '1245',
#   '19',
#   '8',
#   '7',
#   '5',
#   '20',
#   'Yes',
#   'No',
#   '10',
#   '1',
#   '0',
#   '11',
#   '6808',
#   '51'],
#  ['314',
#   'Wasserngrat (Gstaad)',
#   'Switzerland',
#   '1900',
#   '1275',
#   '54',
#   '3',
#   '3',
#   '2',
#   '9',
#   'No',
#   'No',
#   '0',
#   '1',
#   '0',
#   '1',
#   '900',
#   '0'],
#  ['315',
#   'Wispile (Gstaad)',
#   'Switzerland',
#   '1941',
#   '1046',
#   '54',
#   '3',
#   '3',
#   '1',
#   '8',
#   'No',
#   'Yes',
#   '3',
#   '0',
#   '2',
#   '5',
#   '3601',
#   '0'],
#  ['316',
#   'Heiti - Gsteig (Gstaad)',
#   'Switzerland',
#   '1370',
#   '1227',
#   '54',
#   '0',
#   '0',
#   '0',
#   '1',
#   'No',
#   'No',
#   '1',
#   '0',
#   '0',
#   '1',
#   '600',
#   '0'],
#  ['317',
#   'Arosa Lenzerheide',
#   'Switzerland',
#   '2865',
#   '1229',
#   '63',
#   '111',
#   '87',
#   '27',
#   '225',
#   'Yes',
#   'Yes',
#   '24',
#   '18',
#   '8',
#   '50',
#   '63936',
#   '0'],
#  ['318',
#   'Villars -\u200b Gryon / Les Diablerets',
#   'Switzerland',
#   '2120',
#   '1224',
#   '54',
#   '51',
#   '45',
#   '4',
#   '100',
#   'Yes',
#   'No',
#   '20',
#   '9',
#   '4',
#   '33',
#   '38905',
#   '0'],
#  ['319',
#   'Verbier (4 Vallées)',
#   'Switzerland',
#   '3330',
#   '821',
#   '66',
#   '107',
#   '202',
#   '103',
#   '412',
#   'Yes',
#   'Yes',
#   '39',
#   '17',
#   '19',
#   '75',
#   '85022',
#   '0'],
#  ['320',
#   'Nendaz (4 Vallées)',
#   'Switzerland',
#   '3330',
#   '821',
#   '66',
#   '107',
#   '202',
#   '103',
#   '412',
#   'Yes',
#   'Yes',
#   '39',
#   '17',
#   '19',
#   '75',
#   '85022',
#   '0'],
#  ['321',
#   'Thyon (4 Vallées)',
#   'Switzerland',
#   '3330',
#   '821',
#   '66',
#   '107',
#   '202',
#   '103',
#   '412',
#   'Yes',
#   'Yes',
#   '39',
#   '17',
#   '19',
#   '75',
#   '85022',
#   '0'],
#  ['322',
#   'Veysonnaz (4 Vallées)',
#   'Switzerland',
#   '3330',
#   '821',
#   '66',
#   '107',
#   '202',
#   '103',
#   '412',
#   'Yes',
#   'Yes',
#   '39',
#   '17',
#   '19',
#   '75',
#   '85022',
#   '0'],
#  ['323',
#   'Ischgl',
#   'Austria',
#   '2872',
#   '1377',
#   '52',
#   '47',
#   '142',
#   '49',
#   '238',
#   'Yes',
#   'No',
#   '13',
#   '25',
#   '7',
#   '45',
#   '88215',
#   '1200'],
#  ['324',
#   'Kleine Scheidegg / \u200bMännlichen-Grindelwald / \u200bWengen',
#   'Switzerland',
#   '2320',
#   '944',
#   '55',
#   '33',
#   '56',
#   '13',
#   '102',
#   'No',
#   'No',
#   '10',
#   '10',
#   '6',
#   '26',
#   '29250',
#   '0'],
#  ['325',
#   'Kranjska Gora',
#   'Slovenia',
#   '1215',
#   '800',
#   '33',
#   '10',
#   '8',
#   '2',
#   '20',
#   'Yes',
#   'Yes',
#   '15',
#   '5',
#   '0',
#   '20',
#   '17774',
#   '0'],
#  ['326',
#   'Kuühtai',
#   'Austria',
#   '2520',
#   '1938',
#   '37',
#   '6',
#   '26',
#   '8',
#   '41',
#   'Yes',
#   'Yes',
#   '6',
#   '5',
#   '1',
#   '12',
#   '17254',
#   '80'],
#  ['327',
#   'La Grave - La Meije',
#   'France',
#   '3534',
#   '1470',
#   '49',
#   '3',
#   '0',
#   '0',
#   '3',
#   'No',
#   'No',
#   '1',
#   '0',
#   '2',
#   '3',
#   '1460',
#   '0'],
#  ['328',
#   'Espace San Bernardo – La Rosière/\u200bLa Thuile',
#   'France',
#   '2641',
#   '1176',
#   '43',
#   '55',
#   '83',
#   '22',
#   '160',
#   'Yes',
#   'No',
#   '21',
#   '18',
#   '1',
#   '40',
#   '53669',
#   '0'],
#  ['329',
#   'La Thuile / La Rosière - Espace San Bernardo',
#   'Italy',
#   '2641',
#   '1176',
#   '43',
#   '55',
#   '83',
#   '22',
#   '160',
#   'Yes',
#   'No',
#   '21',
#   '18',
#   '1',
#   '40',
#   '53669',
#   '0'],
#  ['330',
#   'La Tania-Val Thorens/\u200bLes Menuires/\u200bMéribel (Les 3 Vallées)',
#   'France',
#   '3230',
#   '1110',
#   '61',
#   '312',
#   '216',
#   '72',
#   '600',
#   'Yes',
#   'Yes',
#   '62',
#   '63',
#   '40',
#   '165',
#   '250860',
#   '2383'],
#  ['331',
#   'The Lecht',
#   'United Kingdom',
#   '775',
#   '637',
#   '33',
#   '5',
#   '9',
#   '4',
#   '18',
#   'Yes',
#   'Yes',
#   '12',
#   '1',
#   '0',
#   '13',
#   '9750',
#   '0'],
#  ['332',
#   'Les Deux alpes',
#   'France',
#   '3560',
#   '1280',
#   '49',
#   '110',
#   '56',
#   '34',
#   '200',
#   'Yes',
#   'Yes',
#   '26',
#   '21',
#   '7',
#   '54',
#   '72334',
#   '224'],
#  ['333',
#   'Les Contamines-\u200bHauteluce',
#   'France',
#   '2437',
#   '1164',
#   '39',
#   '40',
#   '60',
#   '20',
#   '120',
#   'No',
#   'Yes',
#   '12',
#   '8',
#   '4',
#   '24',
#   '33972',
#   '0'],
#  ['334',
#   'Les Orres',
#   'France',
#   '2720',
#   '1550',
#   '35',
#   '30',
#   '60',
#   '10',
#   '100',
#   'Yes',
#   'No',
#   '11',
#   '9',
#   '0',
#   '20',
#   '21020',
#   '190'],
#  ['335',
#   'Courmayeur / Chécrouit -\u200b Val Veny',
#   'Italy',
#   '2755',
#   '1205',
#   '46',
#   '16',
#   '21',
#   '4',
#   '41',
#   'Yes',
#   'No',
#   '4',
#   '8',
#   '6',
#   '18',
#   '24497',
#   '280'],
#  ['336',
#   'Zermatt - Matterhorn',
#   'Switzerland',
#   '3899',
#   '1562',
#   '81',
#   '75',
#   '220',
#   '27',
#   '322',
#   'Yes',
#   'No',
#   '21',
#   '22',
#   '20',
#   '63',
#   '93464',
#   '1060'],
#  ['337',
#   'Mayrhofen-Penken/\u200bAhorn/\u200bRastkogel/\u200bEggalm',
#   'Austria',
#   '2500',
#   '630',
#   '52',
#   '40',
#   '66',
#   '30',
#   '136',
#   'Yes',
#   'No',
#   '31',
#   '17',
#   '9',
#   '57',
#   '82432',
#   '286'],
#  ['338',
#   'Nevis Range',
#   'United Kingdom',
#   '655',
#   '91',
#   '36',
#   '7',
#   '10',
#   '3',
#   '20',
#   'No',
#   'No',
#   '8',
#   '3',
#   '1',
#   '12',
#   '10350',
#   '0'],
#  ['339',
#   'Obertauern',
#   'Austria',
#   '2313',
#   '1630',
#   '46',
#   '61',
#   '35',
#   '4',
#   '100',
#   'Yes',
#   'Yes',
#   '11',
#   '18',
#   '2',
#   '31',
#   '50797',
#   '280'],
#  ['340',
#   'Levi',
#   'Finland',
#   '531',
#   '206',
#   '43',
#   '15',
#   '19',
#   '2',
#   '37',
#   'Yes',
#   'Yes',
#   '25',
#   '2',
#   '2',
#   '29',
#   '30110',
#   '267'],
#  ['341',
#   'Ruka',
#   'Finland',
#   '492',
#   '291',
#   '43',
#   '9',
#   '7',
#   '2',
#   '18',
#   'Yes',
#   'Yes',
#   '17',
#   '5',
#   '0',
#   '22',
#   '22915',
#   '70'],
#  ['342',
#   'Hedelands Skicenter',
#   'Denmark',
#   '78',
#   '33',
#   '17',
#   '0',
#   '0',
#   '0',
#   '0',
#   'no report',
#   'No',
#   '0',
#   '0',
#   '0',
#   '0',
#   '1600',
#   '4'],
#  ['343',
#   'Saalbach Hinterglemm Leogang Fieberbrunn (Skicircus)',
#   'Austria',
#   '2096',
#   '830',
#   '53',
#   '140',
#   '112',
#   '18',
#   '270',
#   'Yes',
#   'Yes',
#   '21',
#   '22',
#   '28',
#   '71',
#   '135104',
#   '927'],
#  ['344',
#   'Fieberbrunn - Saalbach Hinterglemm Leogang (Skicircus)',
#   'Austria',
#   '2096',
#   '830',
#   '53',
#   '140',
#   '112',
#   '18',
#   '270',
#   'Yes',
#   'Yes',
#   '21',
#   '22',
#   '28',
#   '71',
#   '135104',
#   '927'],
#  ['345',
#   'Saas-Fee',
#   'Switzerland',
#   '3573',
#   '1800',
#   '63',
#   '20',
#   '60',
#   '20',
#   '100',
#   'Yes',
#   'No',
#   '14',
#   '2',
#   '9',
#   '25',
#   '25160',
#   '102'],
#  ['346',
#   'Sainte-Foy-Tarentaise',
#   'France',
#   '2620',
#   '1550',
#   '31',
#   '10',
#   '25',
#   '6',
#   '41',
#   'No',
#   'No',
#   '2',
#   '4',
#   '0',
#   '6',
#   '7100',
#   '10'],
#  ['347',
#   'Val Senales Glacier',
#   'Italy',
#   '3212',
#   '2011',
#   '44',
#   '8',
#   '7',
#   '11',
#   '27',
#   'Yes',
#   'No',
#   '6',
#   '6',
#   '2',
#   '14',
#   '15838',
#   '0'],
#  ['348',
#   'Serfaus-Fiss-Ladis',
#   'Austria',
#   '2820',
#   '1200',
#   '49',
#   '47',
#   '123',
#   '28',
#   '198',
#   'Yes',
#   'Yes',
#   '40',
#   '16',
#   '12',
#   '68',
#   '78460',
#   '1250'],
#  ['349',
#   'Serre Chevalier-Briançon/\u200bChantemerle/\u200bVilleneuve-la-Salle/\u200bLe Monêtier-les-Bains',
#   'France',
#   '2800',
#   '1200',
#   '49',
#   '138',
#   '80',
#   '32',
#   '250',
#   'Yes',
#   'Yes',
#   '33',
#   '21',
#   '7',
#   '61',
#   '72066',
#   '575'],
#  ['350',
#   'Sestriere ski resort (Via Lattea)',
#   'Italy',
#   '2749',
#   '1372',
#   '48',
#   '96',
#   '220',
#   '84',
#   '400',
#   'No',
#   'Yes',
#   '29',
#   '35',
#   '7',
#   '71',
#   '96433',
#   '0'],
#  ['351',
#   'Silvretta Montafon',
#   'Austria',
#   '2430',
#   '700',
#   '53',
#   '60',
#   '45',
#   '8',
#   '113',
#   'Yes',
#   'No',
#   '25',
#   '18',
#   '10',
#   '53',
#   '67472',
#   '330'],
#  ['352',
#   'Wagrain (Ski amedé)',
#   'Austria',
#   '1980',
#   '740',
#   '52',
#   '30',
#   '81',
#   '4',
#   '115',
#   'Yes',
#   'No',
#   '22',
#   '16',
#   '11',
#   '49',
#   '75398',
#   '600'],
#  ['353',
#   'Flachau (Ski amedé)',
#   'Austria',
#   '1980',
#   '740',
#   '52',
#   '30',
#   '81',
#   '4',
#   '115',
#   'Yes',
#   'No',
#   '22',
#   '16',
#   '11',
#   '49',
#   '75398',
#   '600'],
#  ['354',
#   'Valchiavenna – Madesimo/\u200bCampodolcino',
#   'Italy',
#   '1550',
#   '1082',
#   '39',
#   '13',
#   '28',
#   '5',
#   '48',
#   'Yes',
#   'Yes',
#   '1',
#   '9',
#   '3',
#   '13',
#   '26060',
#   '0'],
#  ['355',
#   'St. Anton (Ski Arlberg)',
#   'Austria',
#   '2811',
#   '1270',
#   '53',
#   '130',
#   '123',
#   '51',
#   '304',
#   'Yes',
#   'No',
#   '53',
#   '45',
#   '15',
#   '113',
#   '145127',
#   '747'],
#  ['356',
#   'Lech (Ski Arlberg)',
#   'Austria',
#   '2811',
#   '1270',
#   '53',
#   '130',
#   '123',
#   '51',
#   '304',
#   'Yes',
#   'No',
#   '53',
#   '45',
#   '15',
#   '113',
#   '145127',
#   '747'],
#  ['357',
#   'Zürs (Ski Arlberg)',
#   'Austria',
#   '2811',
#   '1270',
#   '53',
#   '130',
#   '123',
#   '51',
#   '304',
#   'Yes',
#   'No',
#   '53',
#   '45',
#   '15',
#   '113',
#   '145127',
#   '747'],
#  ['358',
#   'St. Christoph (Ski Arlberg)',
#   'Austria',
#   '2811',
#   '1270',
#   '53',
#   '130',
#   '123',
#   '51',
#   '304',
#   'Yes',
#   'No',
#   '53',
#   '45',
#   '15',
#   '113',
#   '145127',
#   '747'],
#  ['359',
#   'Sierra Nevada-Pradollano',
#   'Spain',
#   '3282',
#   '2100',
#   '47',
#   '50',
#   '49',
#   '7',
#   '107',
#   'Yes',
#   'Yes',
#   '5',
#   '14',
#   '2',
#   '21',
#   '59205',
#   '350'],
#  ['360',
#   'St. Johann in Tirol',
#   'Austria',
#   '1604',
#   '659',
#   '44',
#   '16',
#   '23',
#   '3',
#   '43',
#   'No',
#   'Yes',
#   '12',
#   '4',
#   '4',
#   '20',
#   '21100',
#   '260'],
#  ['361',
#   'Bad Gastein',
#   'Austria',
#   '2300',
#   '860',
#   '52',
#   '30',
#   '52',
#   '2',
#   '86',
#   'Yes',
#   'No',
#   '10',
#   '9',
#   '7',
#   '26',
#   '32699',
#   '800'],
#  ['362',
#   'Kronplatz (Plan de Corones)',
#   'Italy',
#   '2275',
#   '973',
#   '54',
#   '52',
#   '42',
#   '25',
#   '119',
#   'Yes',
#   'Yes',
#   '6',
#   '5',
#   '21',
#   '32',
#   '71205',
#   '450'],
#  ['363',
#   'Gargellen',
#   'Austria',
#   '2300',
#   '1423',
#   '47',
#   '20',
#   '5',
#   '2',
#   '28',
#   'Yes',
#   'No',
#   '5',
#   '3',
#   '1',
#   '9',
#   '10650',
#   '83'],
#  ['364',
#   'Hochschwarzeck',
#   'Germany',
#   '1385',
#   '1030',
#   '22',
#   '4',
#   '0',
#   '0',
#   '4',
#   'No',
#   'No',
#   '3',
#   '1',
#   '0',
#   '4',
#   '2880',
#   '0'],
#  ['365',
#   'Arcalís-Ordino (Vallnord)',
#   'Andorra',
#   '2625',
#   '1940',
#   '37',
#   '13',
#   '14',
#   '3',
#   '30',
#   'Yes',
#   'No',
#   '10',
#   '4',
#   '1',
#   '15',
#   '14240',
#   '106'],
#  ['366',
#   'Hemsedal',
#   'Norway',
#   '1450',
#   '620',
#   '46',
#   '29',
#   '10',
#   '4',
#   '44',
#   'Yes',
#   'Yes',
#   '15',
#   '6',
#   '0',
#   '21',
#   '22921',
#   '325'],
#  ['367',
#   'Sölden',
#   'Austria',
#   '3340',
#   '1350',
#   '53',
#   '70',
#   '44',
#   '29',
#   '144',
#   'Yes',
#   'Yes',
#   '12',
#   '16',
#   '8',
#   '36',
#   '70370',
#   '363'],
#  ['368',
#   'Stubai Glacier',
#   'Austria',
#   '3212',
#   '1697',
#   '46',
#   '19',
#   '15',
#   '4',
#   '38',
#   'Yes',
#   'No',
#   '14',
#   '7',
#   '5',
#   '26',
#   '39784',
#   '69'],
#  ['369',
#   'Elfer Neustift',
#   'Austria',
#   '2080',
#   '981',
#   '29',
#   '0',
#   '7',
#   '0',
#   '7',
#   'No',
#   'No',
#   '3',
#   '0',
#   '1',
#   '4',
#   '2980',
#   '0'],
#  ['370',
#   'Val Gardena',
#   'Italy',
#   '2518',
#   '1236',
#   '54',
#   '52',
#   '105',
#   '18',
#   '175',
#   'Yes',
#   'No',
#   '29',
#   '41',
#   '14',
#   '84',
#   '121914',
#   '630'],
#  ['371',
#   'Val Thorens (Les 3 Vallées)',
#   'France',
#   '3230',
#   '1110',
#   '61',
#   '312',
#   '216',
#   '72',
#   '600',
#   'Yes',
#   'Yes',
#   '62',
#   '63',
#   '40',
#   '165',
#   '250860',
#   '2383'],
#  ['372',
#   'Montgenèvre (Via Lattea)',
#   'France',
#   '2749',
#   '1372',
#   '48',
#   '96',
#   '220',
#   '84',
#   '400',
#   'No',
#   'Yes',
#   '29',
#   '35',
#   '7',
#   '71',
#   '96433',
#   '0'],
#  ['373',
#   'Sauze d’Oulx (Via Lattea)',
#   'Italy',
#   '2749',
#   '1372',
#   '48',
#   '96',
#   '220',
#   '84',
#   '400',
#   'No',
#   'Yes',
#   '29',
#   '35',
#   '7',
#   '71',
#   '96433',
#   '0'],
#  ['374',
#   'Gressoney - La-Trinite (Monterosa Ski)',
#   'Italy',
#   '3275',
#   '1212',
#   '43',
#   '23',
#   '94',
#   '15',
#   '132',
#   'Yes',
#   'No',
#   '9',
#   '9',
#   '12',
#   '30',
#   '31984',
#   '655'],
#  ['375',
#   'Champoluc (Monterosa Ski)',
#   'Italy',
#   '3275',
#   '1212',
#   '43',
#   '23',
#   '94',
#   '15',
#   '132',
#   'Yes',
#   'No',
#   '9',
#   '9',
#   '12',
#   '30',
#   '31984',
#   '655'],
#  ['376',
#   'Zauchensee',
#   'Austria',
#   '2188',
#   '1000',
#   '52',
#   '23',
#   '16',
#   '4',
#   '44',
#   'Yes',
#   'No',
#   '9',
#   '6',
#   '4',
#   '19',
#   '25988',
#   '113']]

# %%
dict = {'some data': 55, "other data": 83, "more data": 23}

# %% [markdown]
# # Frequencies & Percentages
#
# Frequency is the number of times a unique value is found. This is useful for extracting proprotions and percentages from your data.
#
# * countries
# * night ski
# * snowparks
# * nightskis

# %%
country_freq = {}
# loop for the length of ski_data
for i in range(len(ski_data)):
    # index 2 = country
    country = ski_data[i][2]
    # if found increase, else add initial count
    if country in country_freq:
        country_freq[country] += 1
    else:
        country_freq[country] = 1

        # check
print(country_freq)
# Out:
# {'Austria': 89, 'Andorra': 5, 'Southern Russia': 4, 'Poland': 2, 'Bulgaria': 4, 'Bosnia and Herzegovina': 1, 'Slovenia': 4, 'France': 83, 'Switzerland': 61, 'Germany': 24, 'Spain': 8, 'Italy': 44, 'Sweden': 6, 'Norway': 10, 'Ukraine': 1, 'Finland': 3, 'Serbia': 1, 'Slovakia': 5, 'Siberia': 1, 'Czech Republic': 2, 'Romania': 2, 'Greece': 1, 'United Kingdom': 4, 'Liechtenstein': 1, 'Lithuania': 1, 'Denmark': 8, 'Netherlands': 1}

# %%
country_proportions = {}
country_percents = {}
for freq in country_freq:
    country_proportions = country_freq[freq] / len(ski_data)
    country_percents[freq] = country_proportions * 100
   # print(country_proportions)
   # print(freq, " ", country_percents)
    print(country_percents)
# Out:
# {'Austria': 23.670212765957448}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213, 'Romania': 0.5319148936170213}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213, 'Romania': 0.5319148936170213, 'Greece': 0.26595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213, 'Romania': 0.5319148936170213, 'Greece': 0.26595744680851063, 'United Kingdom': 1.0638297872340425}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213, 'Romania': 0.5319148936170213, 'Greece': 0.26595744680851063, 'United Kingdom': 1.0638297872340425, 'Liechtenstein': 0.26595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213, 'Romania': 0.5319148936170213, 'Greece': 0.26595744680851063, 'United Kingdom': 1.0638297872340425, 'Liechtenstein': 0.26595744680851063, 'Lithuania': 0.26595744680851063}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213, 'Romania': 0.5319148936170213, 'Greece': 0.26595744680851063, 'United Kingdom': 1.0638297872340425, 'Liechtenstein': 0.26595744680851063, 'Lithuania': 0.26595744680851063, 'Denmark': 2.127659574468085}
# {'Austria': 23.670212765957448, 'Andorra': 1.3297872340425532, 'Southern Russia': 1.0638297872340425, 'Poland': 0.5319148936170213, 'Bulgaria': 1.0638297872340425, 'Bosnia and Herzegovina': 0.26595744680851063, 'Slovenia': 1.0638297872340425, 'France': 22.074468085106382, 'Switzerland': 16.22340425531915, 'Germany': 6.382978723404255, 'Spain': 2.127659574468085, 'Italy': 11.702127659574469, 'Sweden': 1.5957446808510638, 'Norway': 2.6595744680851063, 'Ukraine': 0.26595744680851063, 'Finland': 0.7978723404255319, 'Serbia': 0.26595744680851063, 'Slovakia': 1.3297872340425532, 'Siberia': 0.26595744680851063, 'Czech Republic': 0.5319148936170213, 'Romania': 0.5319148936170213, 'Greece': 0.26595744680851063, 'United Kingdom': 1.0638297872340425, 'Liechtenstein': 0.26595744680851063, 'Lithuania': 0.26595744680851063, 'Denmark': 2.127659574468085, 'Netherlands': 0.26595744680851063}

# %%
ski_data[0][1]
# Out:
# 'Alpendorf (Ski amedé)'

# %%
ski_data[0][1].split(" ")
# Out:
# ['Alpendorf', '(Ski', 'amedé)']

# %%
ski_data[0][1][0:9]
# Out:
# 'Alpendorf'
